# %%
import pyaudio
import numpy as np
import pylab
import matplotlib.pyplot as plt
from scipy.io import wavfile
import time
import sys

# %%
#wf = wave.open('/home/aalmela/Dropbox/Public/EAIII/5-Simulaciones/Matlab/audio/1V_3khz_-_3V_1khz.wav', 'rb')

fs = wf.getframerate()
bytes_per_sample = wf.getsampwidth()
bits_per_sample  = bytes_per_sample * 8
dtype = 'int{0}'.format(bits_per_sample)
channels = wf.getnchannels()

print(fs)
print(bytes_per_sample)
print(dtype)
print(channels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-02a81e7d23e1> in <module>
#       1 #wf = wave.open('/home/aalmela/Dropbox/Public/EAIII/5-Simulaciones/Matlab/audio/1V_3khz_-_3V_1khz.wav', 'rb')
#       2
# ----> 3 fs = wf.getframerate()
#       4 bytes_per_sample = wf.getsampwidth()
#       5 bits_per_sample  = bytes_per_sample * 8
#
# NameError: name 'wf' is not defined

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pyaudio
import numpy as np
import pylab
import time

RATE = 48000
CHUNK = int(RATE/20) # RATE / number of updates per second


def soundplot(stream):
    t1=time.time()
    data = np.fromstring(stream.read(CHUNK),dtype=np.int16)
    return data


p=pyaudio.PyAudio()

stream=p.open(format=pyaudio.paInt16,channels=1,rate=RATE,input=True,frames_per_buffer=CHUNK)


fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title('Microfono')
plt.ion()

fig.show()
fig.canvas.draw()
for i in range(int(20*RATE/CHUNK)): #do this for 10 seconds
    ax.clear()
    ax.plot(soundplot(stream))
    ax.set_xlim([0, 2000])
    ax.set_ylim([50000, -50000])        
    fig.canvas.draw()

stream.stop_stream()
stream.close()
p.terminate()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /home/aalmela/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   from ipykernel import kernelapp as app
# /home/aalmela/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   from ipykernel import kernelapp as app
# /home/aalmela/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   from ipykernel import kernelapp as app
# ...

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pyaudio
import numpy as np
import pylab
import time


fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()
for i in range(int(20*RATE/CHUNK)): #do this for 10 seconds
    ax.clear()
    ax.plot(np.random.normal(0,1,100) )
    ax.set_xlim([0, 100])
    ax.set_ylim([10, -10])        
    fig.canvas.draw()

stream.stop_stream()
stream.close()
p.terminate()
# Out:
# <img src="data:image/png;base64,..." width="640">
