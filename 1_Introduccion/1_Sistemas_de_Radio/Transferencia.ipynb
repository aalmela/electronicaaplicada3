# %%
from scipy.optimize import curve_fit

import numpy as np
from sympy.plotting import plot
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize'] = 13,10
plt.rcParams['lines.linewidth'] = 2

# %%
def So(vin):
    vout= list()
    for v in vin:
        i = 0.               if (v < 0.)  else 0
        i = (1.)*(v-0.) if (v >= 0  and v < 5) else i
        i = (5.)            if (v >= 5 ) else i
        vout.append(i)
    return vout

def Soc(vi):
    return a*cos()+

xdata = np.linspace(0, 6, 50)

plt.plot(xdata, So(xdata))

# %%
# This will plot sine and its Taylor approximations

p = plot(So(x),taylor(sin(x),0,1),taylor(sin(x),0,3),taylor(sin(x),0,5),
         (x,-3.5,3.5),legend=True, show=False)

p[0].line_color = 'blue'
p[1].line_color = 'green'
p[2].line_color = 'firebrick'
p[3].line_color = 'black'
p.title = 'Taylor Series Expansion for Sine'
p.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sympy/plotting/experimental_lambdify.py in __call__(self, args, kwargs)
#     194             #The result can be sympy.Float. Hence wrap it with complex type.
# --> 195             result = complex(self.lambda_func(args))
#     196             if abs(result.imag) > 1e-7 * abs(result):
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/expr.py in __complex__(self)
#     284         re, im = result.as_real_imag()
# --> 285         return complex(float(re), float(im))
#     286
#
# ~/anaconda3/lib/python3.7/site-packages/sympy/core/expr.py in __float__(self)
#     279             raise TypeError("can't convert complex to float")
# --> 280         raise TypeError("can't convert expression to float")
#     281
#
# TypeError: can't convert expression to float
#
# ...
