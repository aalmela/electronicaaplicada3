# %%
import skrf as rf
from pylab import *


from skrf import Network, Frequency



resonador = Network('/home/aalmela/Documentos/resonator_2r7u_100mhz.s1p')

# %%
resonador.plot_s_smith(lw=2)

# %%
y_resonador = resonador.y

# %%
# %matplotlib notebook
yabs = [20*np.log10(abs(y[0][0])) for y in y_resonador] 
plt.plot(resonador.f,yabs,'r,')

plt.xlim([10e3,40e6])
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# (10000.0, 40000000.0)

# %%
resonador[:,20].plot_y_db()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-abeb060eb350> in <module>
# ----> 1 resonador[:,20].plot_y_db()
#
# ~/anaconda3/lib/python3.8/site-packages/skrf/network.py in __getitem__(self, key)
#     786                 else:
#     787                     if self.port_names is None:
# --> 788                         raise ValueError("Can't index without named ports")
#     789                     try:
#     790                         p1_index = self.port_names.index(p1_name)
#
# ValueError: Can't index without named ports

# %%
resonador.plot_s_db()
