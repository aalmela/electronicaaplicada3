# %% [markdown]
# # Ejercicio
#
#
# El diagrama en bloques de la figura corresponde a un receptor de Banda Aeronáutica ($118 MHz$ a $137 MHz$).
#
#
# Rechazo de frecuencia imagen  $\mid A_v{@f_{Img}} \mid = 55 dB$.
#
# Separación entre canales de $50 KHz$.
#
# Está sintonizado para recibir el canal de  $F_c = 120 MHz$, de ancho de banda del canal de $BW = 15 KHz$, el cual se encuentra modulado al $50\%$  por un tono único de $3\,KHz$.
#
#
# ![ex 2.13](fig/canvas.png)
# Fig. Diagrama en bloques
#
# Todos los elementos activos (Amplificadores, mezclador y detector) son lineales y de parámetros constantes dentro de toda la banda de interés.
#
# ## Etapa RF
#
# La antena presenta una impedancia $R_{a}= 50 \Omega$ en toda la banda de interés.
#
#
# Circuito sincronico sintonizado en $f = 120 MHz$.
#
# Todos los sintonizados están adaptados a máxima transferencia de energía a Q constate.
#
# Los transformadores empleados tiene una inductancia cuyo valor es $L_1 =200 nHy$, $Q_{oL} = 80$ y $N = 10$ espiras $^*$
#
#
# ![ex 2.13](fig/RF_2020.png)
#
# Los parámetros del transistor de RF:
#
# $Y_{11} = (  1  + j4 ) mS$
#
# $Y_{12} \sim 0 S$
#
# $Y_{21} = (  100 - j10  ) mS$
#
# $Y_{22} = (0.2  + j8) mS$
#
#
# ## Mezclador
#
# Los parámetros del mezclador:
#
# $Y_{in}  = ( 1 ) mS$
#
# $Y_{out} = (0.1) mS$
#
# $Av = 4 dB$
#
# $F_{ol} = F_{c} + F_{FI}$
#
#
#
#
# ## Etapa IF
#
# El detector presenta una impedancia de $R_{det}= 500 \Omega$
#
# Todos los sintonizados están adaptados a máxima transferencia de energía a Q constate.
#
#
# $F_{FI}= 10.7 MHz$
#
# ![ex 2.13](fig/IF_2020.png)
#
# Los parámetros del transistor de FI:
#
# $Y_{11} = (  1  + j0.2) mS$
#
# $Y_{12} \sim 0 S$
#
# $Y_{21} = (   40 - j2  ) mS$
#
# $Y_{22} = (0.1 + j0.4) mS$
#
#
#
# Los transformadores empleados tiene una inductancia cuyo valor es $L_1 =4 \mu Hy$, $Q_{oL} = 80$ y $N = 20$ espiras $^**$
#
# Capacitores con $Q_{oC} = \infty$.
#
#
#
#
#
# $^*$ https://www.electronics-tutorials.com/filters/if-amplifier-transformers.htm
#
# $^**$https://www.murata.com/en-global/products/inductor/variable
#
# https://www.murata.com/en-global/products/inductor/chip/overview/lineup/rf2#tab-area

# %% [markdown]
# Determinar:
#
# 1. Los $Q_{c}$ para las etapas de RF.
#
# 2. Atenuacion del canal adyacente.
#
# 3. Los valores para N1, N2, N3, N4 y C1.
#
# 4. Los valores para L2, C2, C3, C4 y C5.
#
# 5. Calcular la ganancia de tensión del amplificador de RF.
#
# 6. Calcular la ganancia de tensión del amplificador de FI.
#
# 7. Calcular la ganancia de tensión total.
#
# 8. Calcular la ganancia de potencia de cada amplificador y del amplificador total (10 puntos) (G = $\frac{P_{RL}}{P{in}}$ ).
#
# 9. Se re-sintoniza a $F_{rf} = 137 MHz$. Calcular el rechazo variando solamente $C_1$ y manteniendo constante $L_1$
#
# 10. Idem 9, calcular el rechazo variando solamente $L_1$ y manteniendo constante $C_1$, comparar con el resultado anterior.
