# %% [markdown]
# # Ejercicio
#
#
# El circuito de la figura corresponde a un receptor de Banda Aeronáutica ($118 MHz$ a $137 MHz$).
# Está sintonizado para recibir el canal de  $F_c = 120 MHz$, de ancho de banda del canal de $BW = 100 KHz$, y
#  modulado al $50\%$  por un tono único de $15\,KHz$.
#
#
#
#
# ## Diagrama en bloques
#
#
# ![ex 2.13](fig/canvas.png)
#
#
#
#
# Los parámetros del mezclador:
#
# $Y_{in}  = ( 1 ) mS$
#
# $Y_{out} = (0.1) mS$
#
# $Av = 4 dB$
#
#
# Todos los elementos activos (Amplificadores, mezclador y detector) son lineales y de parámetros constantes dentro de toda la banda de interés.
#
#
# Ambos amplificadores (RF y FI) son sincrónicos.
# $F_{ol} = F_{c} + F_{FI}$, $F_{FI}= 10.7 MHz$
#
#
# La antena presenta una impedancia $R_{a}= 50 \Omega$ en toda la banda de interés.
#
# El detector presenta una impedancia de $R_{det}= 500 \Omega$
#
#
# Todos los tanques están adaptados a máxima transferencia de energía a Q constate.
#
# Las bobinas empleadas para el amplificador de RF poseen : $Q_{oL} = 80$ y $N = 10$ espiras cuyo valor es $L_1 =20 nHy$.
#
# Las bobinas empleadas para el amplificador de FI poseen : $Q_{oL} = 100$.
#
# Capacitores con $Q_{oC} = \infty$.
#
# Rechazo de frecuencia imagen  $\mid A_v{@f_{Img}} \mid = 55 dB$.
#
#
#
#
#
#
# ## Circuito RF
#
#
#
# ![ex 2.13](fig/RF_2020.png)
#
# Los parámetros del transistor de RF:
#
# $Y_{11} = (  1  + j4 ) mS$
#
# $Y_{12} \sim 0 S$
#
# $Y_{21} = (  100 - j10  ) mS$
#
# $Y_{22} = (0.2  + j8) mS$
#
# Nota: Para los cálculos, desestimar las capacidades del transistor si  son despreciables respecto al capacitor externos.
#
# ## Circuito IF
#
#
#
# ![ex 2.13](fig/IF_2020.png)
#
# Los parámetros del transistor de FI:
#
# $Y_{11} = (  1  + j0.2) mS$
#
# $Y_{12} \sim 0 S$
#
# $Y_{21} = (   40 - j2  ) mS$
#
# $Y_{22} = (0.1 + j0.4) mS$
#
#
#
# Nota: Para los cálculos, desestimar las capacidades del transistor si  son despreciables respecto al capacitor externos.

# %% [markdown]
# Determinar:
#
# 1. Los $Q_{c}$ para las etapas de RF (10 puntos).
#
# 2. Los $Q_{c}$ para las etapas de IF (10 puntos).
#
# 3. Los valores para N1, N2, N3, N4 y C1 (10 puntos).
#
# 4. Los valores para L2, C2, C3, C4 y C5. (10 puntos).
#
# 5. Calcular la ganancia de tensión del amplificador de RF (10 puntos).
#
# 6. Calcular la ganancia de tensión del amplificador de FI (10 puntos).
#
# 7. Calcular la ganancia de tensión total (10 puntos).
#
# 8. Calcular la ganancia de potencia de cada amplificador y del amplificador total (10 puntos) (G = $\frac{P_{RL}}{P{in}}$ ).
#
# 9. Se re-sintoniza a $F_{rf} = 137 MHz$. Calcular el rechazo variando solamente $C_1$ y manteniendo constante $L_1$ (10 puntos)
#
# 10. Idem 9, calcular el rechazo variando solamente $L_1$ y manteniendo constante $C_1$, comparar con el resultado anterior (10 puntos).
