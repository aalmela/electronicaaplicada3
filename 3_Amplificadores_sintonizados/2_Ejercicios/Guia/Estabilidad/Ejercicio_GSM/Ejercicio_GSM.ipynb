# %% [markdown]
# <font size="7"> **UTN-FRBA**</font>
#
# <font size="7"> **Electrónica Aplicada III**</font>
#
#
#
#
# Un Rx superheterodino de simple conversión para GSM900, con FI en $70 MHz$, es sintonizado para recibir un canal de $f_c=900 MHz$.
#
# El front-end corresponde a un sistema que emplea Software Defined Radio para realizar la demodulación.
#
# ![ex 2.13](fig/diagrama_a.png)
#
#
#
# ## DATOS DE LAS ETAPAS
#
# ### Amplificador  LNA de RF
# Circuito de señal:
# ![ex 2.13](fig/circuito_c.png)
#
# #### Antena
# $Z_{ant} = 50 \Omega$
#
# $T_e = 500 K$
#
#
# #### Datos del transistor
#
# Parametros admitancia a $900 MHz$, $I_{cq} = 5 mA$, $V_{BE} = 0.7 V$
#
# $y_{11}(900 MHZ) =  4.0 mS +j\, 10.0 mS$
#
# $y_{12}(900 MHZ) =         -j\, 0.2 mS$
#
#
# $y_{21}(900 MHZ) = 40.0 mS -j\, 1.0 mS$
#
#
# $y_{22}(900 MHZ) =  0.1 mS +j\,  2.0 mS$
#
#
#
#
# $|y_{12} \cdot y_{21}| + \Re{(y_{12} \cdot y_{21})} = 7.80 \times 10^{-6} S^2$
#
# **Cifra de ruido del transistor** con condición de máxima transferencia de energia a Q constante: $NF = 1.5 dB$
#
# **Cifra de ruido del transistor** con condición de minima cifra de ruido para $Y_{opt}$ : $NF = 1.0 dB$
#
#
# ### Filtro Butterworth
#
# Frecuencia central:  $F_o = 900\,MHz$
#
# Ancho de banda: $BW_{filtro} = 50\,MHz$
#
# Ancho de banda de ruido equivalente:  $BW_{eq,noise} = 200 MHz$
#
# Ganancia de potencia $G= 0\,dB$, cifra de ruido  $NF= 5\,dB$
#
# ### Mezcladores
# Ganancia de potencia $G= 0\,dB$, cifra de ruido  $NF= 3\,dB$
#
# ### Primer oscilador local
# Senoide pura de $830\,MHz$
#
# ### Primera FI (Amplificador + filtro)
# Frecuencia central:  $F_o = 70\,MHz$
#
# Ancho de banda: $BW_{filtro} = 20\,MHz$
#
# Ancho de banda de ruido equivalente:  $BW_{eq,noise} = 40 MHz$
#
# Ganancia de potencia $G= 60\,dB$
#
# Cifra de ruido  $NF= 10\,dB$
#
# ### Determinar
#
#  1. <span style="color:red">**[1 punto]**</span>  Suponiendo $y_{12} = 0$, calcular $L_1$ y $C_1$ para máxima trasnferencia de energía sobre $r_{11}$ del transistor. ($r_g = 50 \Omega$, inductor $Q_o = 80$, capacitor $Q_o = \infty$)
#
#  2. <span style="color:red">**[1 puntos]**</span>  Suponiendo $y_{12} = 0$ y $R_2= 0$, calcular $L_2$, $C_2$, $L_3$ y $C_3$  para adaptar a la impedancia que presenta el transistor a una carga de $R_L = 50 \Omega$. Tenga en cuenta que la impedancia intermedia entre el adaptador formado por  $L_2$, $C_2$ tiene que presentar una impedancia de $Z_{intermedia} =700 \Omega$ (entra del adaptador formado por $L_3$ y $C_3$)
#
#  3. <span style="color:red">**[1 punto]**</span> Obtenga el coeficiente de Linvill de la etapa y explique conceptualmente que indica el coeficiente.
#
#  4. <span style="color:red">**[1 punto]**</span> Obtenga el coeficiente de Stern de la etapa y explique conceptualmente que indica el coeficiente.
#
#  5. <span style="color:red">**[1 puntos]**</span>  Calcular $R_2$ para que el coeficiente de Stern sea $k = 20$.
#
#  6. <span style="color:red">**[1 puntos]**</span> Suponiendo $y_{12} = 0$, calcular la cifra de ruido de la etapa con $R_2$ calculada en el punto 5. Informar la ganacia de potencia total de la etapa.(Recuerde que para un simple sintonizado adaptado con perdidas $P_{out} = P_{in} (1 - \frac{Q_c}{Q_o})$)
#
#  7. <span style="color:red">**[1 punto]**</span> Suponiendo $y_{12} = 0$, recalcular $C_1$ y $L_1$ para adaptar a minima cifra de ruido ($R_{opt} = 80 \Omega$). Suponiendo $y_{12} = -j\, 0.2 mS$ ¿Cual es el nuevo coeficiente de Stern?
#
#  8. <span style="color:red">**[1 punto]**</span> Suponiendo $y_{12} = 0$, calcular la cifra de ruido de la etapa para la condición de mínima cifra de ruido con $R_2$ calculada en el punto 5 y $C_1$ y $L_1$ calculados en el punto 7. Informar la ganacia de potencia total de la etapa.
#
#  9. <span style="color:red">**[1 punto]**</span> Suponiendo $y_{12} = 0$,  determinar el valor de tensión de la señal en antena cuando a la salida del IF hay una $SNR_o = 20\,dB$ para el circuito de minima de cifra de ruido.
#
#  10. <span style="color:red">**[1 punto]**</span>  Calcular la atenuación de frecuencia imagen de la etapa de RF (tenga en cuenta el LNA y la atenuación  del filtro Buttworth, para el circuito de minima de cifra de ruido. Emplear $R_2$ calculada en el punto 5 y $C_1$ y $L_1$ calculados en el punto 7.
#
# **Asignación de puntaje:**
#
# **Puntaje**
#
# Ítems 1 al 10: 1 punto
#
# **Criterio de corrección p/ítem:**
#
# **Concepto, desarrollo y resultado correcto: total del puntaje**
#
# **Concepto, desarrollo y error de cálculo: mitad del puntaje**
#
# **Error de concepto: Puntaje nulo**
#
# **Criterio de aprobación:**
#
# **Sumatoria de puntos mayor o igual a 6 (Seis)**

# %% [markdown]
# 1. <span style="color:red">**[1 punto]**</span>  Suponiendo $y_{12} = 0$, calcular $L_1$ y $C_1$ para máxima trasnferencia de energía sobre $r_{11}$ del transistor. ($r_g = 50 \Omega$, inductor $Q_o = 80$, capacitor $Q_o = \infty$)
#
# Para este punto tenemos que hacer una conversión serie a paralelo de la resistencia interna del generador $r_g$ a la resistencia que presenta el transistor $r_{11}$.
#
#
#
# $r_g' = r_g (1 +Q_m^2)$
#
# $r_g' = r_{11}$
#
# $Q_m = \sqrt{\frac{r_g'}{r_g} - 1}$
#
# Entonces
#
# $Q_m = \frac{1}{w_o C_1  r_g}$
#
# $C_1 = Q_m w_o  r_g$
#
#
# Conversión serie paralelo del capacitor
#
# $C_1' = \frac{C_1}{(1 + \frac{1}{Q_m^2})}$
#
# $C_1 = 1.77 pF$
#
#
# Agragando la capacidad del transistor
#
# $C_{1t} = c_{11} + C_1'$
#
# La inductancia que sintoniza
#
# $L_1 = \frac{1}{C_{1t} w_o^2}$
#
# $L_1 = 9.82 nHy$
#
#
# El $Q_c$  del circuito
#
# $\frac{1}{Q_c} = \frac{1}{Q_o} + \frac{w_o L_1}{\frac{r_{11}}{2}}$
#
# $Q_c = 2.19$

# %% [markdown]
# 2. <span style="color:red">**[1 puntos]**</span>  Suponiendo $y_{12} = 0$ y $R_2= 0$, calcular $L_2$, $C_2$, $L_3$ y $C_3$  para adaptar a la impedancia que presenta el transistor a una carga de $R_L = 50 \Omega$. Tenga en cuenta que la impedancia intermedia entre el adaptador formado por  $L_2$, $C_2$ tiene que presentar una impedancia de $Z_{intermedia} =700 \Omega$ (entra del adaptador formado por $L_3$ y $C_3$)
#
# $r_i' = r_i (1 +Q_m^2)$
#
# $r_i' = r_{22}$
#
# $Q_m = \sqrt{\frac{r_i'}{r_i} - 1}$
#
# Entonces
#
# $Q_m = \frac{1}{w_o C_2  r_g}$
#
# $C_2 = Q_m w_o  r_i$
#
# $$C_2 = 0.0693 pF$$
#
#
# Conversión serie paralelo del capacitor
#
# $C_2' = \frac{C_2}{(1 + \frac{1}{Q_m^2})}$
#
# Agragando la capacidad del transistor
#
# $C_{2t} = c_{22} + C_2'$
#
# La inductancia que sintoniza
#
# $L_2 = \frac{1}{C_{2t} w_o^2}$
#
# $$L_2 = 74.8 nHy$$
#
# El $Q_c$  del circuito
#
# $\frac{1}{Q_c} = \frac{1}{Q_o} + \frac{w_o L_2}{\frac{r_{22}}{2}}$
#
# $$Q_c = 10.3$$
#
# De igual manera
#
# $r_l' = r_l (1 +Q_m^2)$
#
# $r_l' = r_i$
#
# $Q_m = \sqrt{\frac{r_l'}{r_l} - 1}$
#
# Entonces
#
# $Q_m = \frac{1}{w_o C_3  r_l}$
#
# $C_3 = Q_m w_o  r_i$
#
# $$C_3 = 0.0701 pF$$
#
#
# Conversión serie paralelo del capacitor
#
# $C_3' = \frac{C_3}{(1 + \frac{1}{Q_m^2})}$
#
# Agragando la capacidad del transistor
#
# $C_{3t} =  C_3'$
#
# La inductancia que sintoniza
#
# $L_3 = \frac{1}{C_{3t} w_o^2}$
#
# $$L_3 = 480.7 nHy$$
#
# El $Q_c$  del circuito
#
# $\frac{1}{Q_c} = \frac{1}{Q_o} + \frac{w_o L_3}{\frac{r_{i}}{2}}$
#
# $$Q_c = 10.3$$

# %% [markdown]
#  3. <span style="color:red">**[1 punto]**</span> Obtenga el coeficiente de Linvill de la etapa y explique conceptualmente que indica el coeficiente.
#
#
# $C = \frac{(|y_{12}\cdot y_{21}| +\Re{(y_{12} \cdot y_{21})})}{(2 \Re{y_{11}} \Re{y22}) }$
#
# coeficiente de linvill  $C= 9.75$
#
# El transistor es potencialmente inestable.

# %% [markdown]
# 4. <span style="color:red">**[1 punto]**</span> Obtenga el coeficiente de Stern de la etapa y explique conceptualmente que indica el coeficiente.
#
# $K = \frac{2 (\Re{y_{11}} + g_g)  (\Re{y_{22}}+ g_l)}{|y_{12}\cdot y_{21}| +\Re{(y_{12} \cdot y_{21})}}$
#
# $g_g = \frac{1}{r_{11}} + \frac{1}{r_{p}}$
#
#
#
# $g_l = \frac{1}{r_{22}} + \frac{1}{r_{p}}$
#
# (Se desprecio la carga de $r_{p3}$)
#
# coeficiente de stern $K= 0.48$
#
# El amplificador es inestable.

# %% [markdown]
# 5. <span style="color:red">**[1 puntos]**</span>  Calcular $R_2$ para que el coeficiente de Stern sea $k = 2$.
#
#
# $K = \frac{2 (\Re{y_{11}} + g_g)  (\Re{y_{22}}+ g_l)}{|y_{12}\cdot y_{21}| +\Re{(y_{12} \cdot y_{21})}}$
#
# $2 (\Re{y_{11}} + g_g)  (\Re{y_{22}}+ g_l)  = K \cdot (|y_{12}\cdot y_{21}| +\Re{(y_{12} \cdot y_{21})})$
#
# $(\Re{y_{22}}+ g_l)  = \frac{K \cdot (|y_{12}\cdot y_{21}| +\Re{(y_{12} \cdot y_{21})})}{2 (\Re{y_{11}} + g_g) }$
#
#
#
# $$r_{r2t} = 1.336 K \Omega$$
#
# $Q_m = \frac{r_{p2t} }{(w_o  L_2)}$
#
# $r_{p2ts} = \frac{r_{p2t} }{1+Q_m^2}$
#
#
# $L_{2s}   = \frac{L_2}{(1+\frac{1}{Q_m^2)}}$
#
# $R_2 = w_o  L_{2s}  (\frac{1}{Q_m} - \frac{1}{Q_{o2}})$
#
#
# $$R_2 = 116.9 \Omega$$

# %% [markdown]
# 6. <span style="color:red">**[1 puntos]**</span> Suponiendo $y_{12} = 0$, calcular la cifra de ruido de la etapa con $R_2$ calculada en el punto 5. Informar la ganacia de potencia total de la etapa.(Recuerde que para un simple sintonizado adaptado con perdidas $P_{out} = P_{in} (1 - \frac{Q_c}{Q_o})$)
#
# $F_{tot}=F_{1}+\frac{F_{2}- 1}{G_{1}}+\frac{F_{3}- 1}{G_{1}G_{2}} +\frac{F_{4}- 1}{G_{1}G_{2}G_{3}}$
#
# $G_1 = (1-\frac{Q_{c1}}{Q_{o1}})$
#
#
# $F_1 = \frac{1}{(1-\frac{Q_{c1}}{Q_{o1}})}$
#
# $F_2 = 10^{\frac{1.5}{10}} = 1.41$
#
#
# $G_3 = (1-\frac{Q_{c1}}{Q_{o1}})$
#
#
# $F_3 = \frac{1}{(1-\frac{Q_{c1}}{Q_{o1}})}$
#
# $G_4 = (1-\frac{Q_{c3}}{Q_{o3}})$
#
#
# $F_4 = \frac{1}{(1-\frac{Q_{c1}}{Q_{o1}})}$
#
#
# Ganacia de potencia del transistor
#
# $G_2 = |A_v| \frac{r_{11}}{r_{o}}$
#
# $r_o = \frac{r_{22} r_{p2}}{r_{22} + r_{p2}}$
#
# $|A_v| = |y_{21}|^2 w_o L_2 Q_{c2}$

# %% [markdown]
#  7. <span style="color:red">**[1 punto]**</span> Suponiendo $y_{12} = 0$, recalcular $C_1$ y $L_1$ para adaptar a minima cifra de ruido ($R_{opt} = 80 \Omega$). Suponiendo $y_{12} = -j\, 0.2 mS$ ¿Cual es el nuevo coeficiente de Stern?
#
#
#  Para este punto tenemos que hacer una conversión serie a paralelo de la resistencia interna del generador $r_g$ a la resistencia que presenta el transistor $r_{11}$.
#
#
#
# $r_g' = r_g (1 +Q_m^2)$
#
# $r_g' = Z_{opt}$
#
# $Q_m = \sqrt{\frac{r_g'}{r_g} - 1}$
#
# Entonces
#
# $Q_m = \frac{1}{w_o C_1  r_g}$
#
# $C_1 = Q_m w_o  r_g$
#
#
# Conversión serie paralelo del capacitor
#
# $C_1' = \frac{C_1}{(1 + \frac{1}{Q_m^2})}$
#
# $C_{1o} = 4.57 pF$
#
# Agragando la capacidad del transistor
#
# $C_{1t} = c_{11} + C_1'$
#
# La inductancia que sintoniza
#
# $L_1 = \frac{1}{C_{1t} w_o^2}$
#
# $L_1 = 8.98 nHy$
#
#
# El $Q_c$  del circuito
#
# $\frac{1}{Q_c} = \frac{1}{Q_o} + \frac{w_o L_1}{\frac{r_{11}}{2}}$
#
# $Q_c = 2.39$

# %% [markdown]
#  8. <span style="color:red">**[1 punto]**</span> Suponiendo $y_{12} = 0$, calcular la cifra de ruido de la etapa para la condición de mínima cifra de ruido con $R_2$ calculada en el punto 5 y $C_1$ y $L_1$ calculados en el punto 7. Informar la ganacia de potencia total de la etapa.
#
# $F_{tot}=F_{1}+\frac{F_{2}- 1}{G_{1}}+\frac{F_{3}- 1}{G_{1}G_{2}} +\frac{F_{4}- 1}{G_{1}G_{2}G_{3}}$
#
# $G_1 = (1-\frac{Q_{c1}}{Q_{o1}})$
#
#
# $F_1 = \frac{1}{(1-\frac{Q_{c1}}{Q_{o1}})}$
#
# $F_2 = 10^{\frac{1}{10}} = 1.25$
#
#
# $G_3 = (1-\frac{Q_{c1}}{Q_{o1}})$
#
#
# $F_3 = \frac{1}{(1-\frac{Q_{c1}}{Q_{o1}})}$
#
# $G_4 = (1-\frac{Q_{c3}}{Q_{o3}})$
#
#
# $F_4 = \frac{1}{(1-\frac{Q_{c1}}{Q_{o1}})}$
#
#
# Ganacia de potencia del transistor
#
# $G_2 = |A_v| \frac{r_{11}}{r_{o}}$
#
# $r_o = \frac{r_{22} r_{p2}}{r_{22} + r_{p2}}$
#
# $|A_v| = |y_{21}|^2 w_o L_2 Q_{c2}$
#
#
# $$Fto = 1.29$$
#
# $$NFto = 1.12 dB$$

# %% [markdown]
# 9. <span style="color:red">**[1 punto]**</span> Suponiendo $y_{12} = 0$,  determinar el valor de tensión de la señal en antena cuando a la salida del IF hay una $SNR_o = 20\,dB$ para el circuito de minima de cifra de ruido.
#
# $N_i = k_b T_e B_{eq}$
#
# $B_{eq} = 40 MHz$
#
# $$SNRo = 100.0$$
#
# $$Ni = 0.276 pW$$
#
# $$SNRi = 77.3$$
#
# $$Si = 21.3 pW$$

# %% [markdown]
# 10. <span style="color:red">**[1 punto]**</span>  Calcular la atenuación de frecuencia imagen de la etapa de RF (tenga en cuenta el LNA y la atenuación  del filtro Buttworth, para el circuito de minima de cifra de ruido. Emplear $R_2$ calculada en el punto 5 y $C_1$ y $L_1$ calculados en el punto 7.
#
# $A_1 = \frac{1}{\sqrt{1+Q_1^2 (\frac{f}{f_o}-\frac{f_o}{f})^2}}$
#
# $A_2 = \frac{1}{\sqrt{1+Q_2^2 (\frac{f}{f_o}-\frac{f_o}{f})^2}}$
#
# $A_3 = \frac{1}{\sqrt{1+Q_3^2 (\frac{f}{f_o}-\frac{f_o}{f})^2}}$
#
#
#
# $A_{bt} = \frac{1}{\sqrt{1+(\frac{f-f_c}{f_o-f_c})^{3 \cdot 2} }}$
#
#
# $$Att = 0.00121$$
#
# $$Att = -58.316 dB$$

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy                  # http://scipy.org/
from scipy import signal
import cmath

from IPython.display import Image  
# %matplotlib inline
params = {'legend.fontsize': 24,
          'figure.figsize': (12, 8),
         'axes.labelsize': 24,
         'axes.titlesize': 24,
         'xtick.labelsize':24,
         'ytick.labelsize':24}
plt.rcParams.update(params) 



from IPython.display import Image
import sys 

from skrf import Network, Frequency

# %%
def Linvill(yt):
    y11 = yt[0,0]
    y12 = yt[0,1]
    y21 = yt[1,0]
    y22 = yt[1,1]
    C = (abs(y12*y21)+(y12*y21).real)/(2*y11.real*y22.real)
    print('###############  LINVILL   #####################')
    print( 'coeficiente de linvill C= {:4.2F}' .format(C))
    if C < 1:
        print( 'Es incondicionalmente estable')
    else :
        print( 'Es potencialmente inestable')
    return C

def Stern(gg, gl, yt):
    y11 = yt[0,0]
    y12 = yt[0,1]
    y21 = yt[1,0]
    y22 = yt[1,1]
    K = (2*(y11.real+gg)*(y22.real+gl)) / (abs(y12*y21)+(y12*y21).real)
    n = abs(y12*y21)+(y12*y21).real
    print('$|y_12 \cdot y_21)+\Re (y_12 \cdot y_21) = {:4.2E}'.format(n))
    print('###############  STERN   #####################')
    print( 'coeficiente de stern K= {:4.2F}' .format(K))
    if K > 1:
        print( 'Estable')
    else :
        print( 'Inestable')
    return K

def printS(S1):
    s11 =   S1[0,0]
    s12 =   S1[0,1]
    s21 =   S1[1,0]
    s22 =   S1[1,1]
    print( 's11= {:4.3f}  {:4.2f}' .format(abs(s11),np.angle(s11)*180/np.pi ))
    print( 's12= {:4.3f}  {:4.2f}' .format(abs(s12),np.angle(s12)*180/np.pi ))
    print( 's21= {:4.3f}  {:4.2f}' .format(abs(s21),np.angle(s21)*180/np.pi ))
    print( 's22= {:4.3f}  {:4.2f}' .format(abs(s22),np.angle(s22)*180/np.pi ))

def printY(Y1):
    y11 =   Y1[0,0]
    y12 =   Y1[0,1]
    y21 =   Y1[1,0]
    y22 =   Y1[1,1]
    print( 'y11= {0.real:4.2E}  {0.imag:4.2E}j' .format(y11) )
    print( 'y12= {0.real:4.2E}  {0.imag:4.2E}j' .format(y12) )
    print( 'y21= {0.real:4.2E}  {0.imag:4.2E}j' .format(y21) )
    print( 'y22= {0.real:4.2E}  {0.imag:4.2E}j' .format(y22) )
    print(' ')

    print( 'r11= {0.real:4.2F}' .format(1/y11.real) )
    print( 'c11= {0.real:4.2E}' .format(y11.imag/wo) )


    print( 'gm = {0.real:4.2F}' .format(abs(y21)) )
    print( 'gr = {0.real:4.4F}' .format(abs(y12)) )

    print( 'r22= {0.real:4.2F}' .format(1/y22.real) )
    print( 'c22= {0.real:4.2E}' .format(y22.imag/wo) )

# %%
fo = 900e6
wo = 2*np.pi*fo

rg = 50
rl = 50
rint = 700

Qo1 = 80
Qo2 = 80
Qo3 = 80

NFmte = 1.5 
NFmcr = 1.0
ropt  = 80

Te  = 500
Beq = 40e6
kb  = 1.38e-23
SNRo = 10**(20/10)

Frf  = 900e6
Fif  = 70e6

# Butterworth

BWbt = 50e6
Nbt  = 3

# Parametros del transistor
y11 =    4.0e-3  +10.0e-3j
y12 =            - 0.20e-3j
y21 =   40.0e-3  - 1e-3j
y22 =    0.1e-3  + 2.0e-3j


yt  = np.matrix([[y11, y12],[ y21, y22]])

r11 = 1/y11.real
c11 = y11.imag/wo

r22 = 1/y22.real
c22 = y22.imag/wo

print(c11)
# Out:
# 1.7683882565766149e-12

# %%
### 1 

Qm1 = ((r11/rg) -1)**0.5

print(Qm1)

C1 = 1/(Qm1 * wo * rg)

print( '$$C_1 = {0.real:4.3} pF$$' .format(C1/1e-12))

C1p = C1 /(1 + 1/Qm1**2)

C1t = C1p + c11

L1 = 1/(C1t*wo**2)

print( '$$L_1 = {0.real:4.3} nHy$$' .format(L1/1e-9))


Qc1 = 1/( (1/Qo1)+(wo*L1*2/r11))

print( '$$Q_c = {:4.3}$$' .format(Qc1))
# Out:
# 2.0
# $$C_1 = 1.77 pF$$
# $$L_1 = 9.82 nHy$$
# $$Q_c = 2.19$$

# %%
### 2

Qm2 = ((r22/rint) -1)**0.5

print(Qm2)

C2 = 1/(Qm2 * wo * rint)

print( '$$C_2 = {0.real:4.3} pF$$' .format(C2/1e-12))

C2p = C2 /(1 + 1/Qm2**2)

C2t = C2p + c22

L2 = 1/(C2t*wo**2)

print( '$$L_2 = {0.real:4.3} nHy$$' .format(L2/1e-9))


Qc2 = 1/( (1/Qo2)+(wo*L2*2/r22))

print( '$$Q_c = {:4.3}$$' .format(Qc2))


### 3

Qm3 = ((rint/rl) -1)**0.5

print(Qm3)

C3 = 1/(Qm3 * wo * rint)

print( '$$C_3 = {0.real:4.3} pF$$' .format(C3/1e-12))

C3p = C3 /(1 + 1/Qm3**2)

C3t = C3p

L3 = 1/(C3p*wo**2)

print( '$$L_3 = {0.real:4.4} nHy$$' .format(L3/1e-9))


Qc3 = 1/( (1/Qo3)+(wo*L3*2/rint))

print( '$$Q_c = {:4.3}$$' .format(Qc2))
# Out:
# 3.6449573777637356
# $$C_2 = 0.0693 pF$$
# $$L_2 = 74.8 nHy$$
# $$Q_c = 10.3$$
# 3.605551275463989
# $$C_3 = 0.0701 pF$$
# $$L_3 = 480.7 nHy$$
# $$Q_c = 10.3$$

# %%
Linvill(yt)
# Out:
# ###############  LINVILL   #####################
# coeficiente de linvill C= 9.75
# Es potencialmente inestable
# 9.75312451187128

# %%
## MTEQ
rp1 =  Qo1 * wo * L1 

gg  = 1/r11 + 1/rp1


rp2 = Qo2 * wo * L2 
gl  = 1/r22 + 1/rp2


K = Stern(gg, gl, yt)
# Out:
# $|y_12 \cdot y_21)+\Re (y_12 \cdot y_21) = 7.80E-06
# ###############  STERN   #####################
# coeficiente de stern K= 0.48
# Inestable

# %%
K2 = 2

gl = (K2 * (abs(y12*y21)+(y12*y21).real)/ (2*(y11.real+gg))) - y22.real 

rp2t = 1/(gl - y22.real )

print( '$$R_r2t = {0.real:4.4} Omega$$' .format(rp2t))

Qm = rp2t / (wo * L2)

rp2ts = rp2t /(1+Qm**2)

L2s   = L2 /(1+1/Qm**2)

R2 = wo * L2s * (1/Qm - 1/Qo2)

print( '$$R_2 = {0.real:4.4} Omega$$' .format(R2))
# Out:
# $$R_r2t = 1.336e+03 Omega$$
# $$R_2 = 116.9 Omega$$

# %%
G1 = (1-Qc1/Qo1)

F1 = 1/G1 

G3 = (1-Qc2/Qo2)

F3 = 1/G3 

G4 = (1-Qc3/Qo3)

F4 = 1/G4

F2 = 10**(NFmte/10)

Av = abs(y21) * Qc2* wo * L2

ro = r22 * rp2 / (r22 + rp2)
G2 = Av**2 * r11/ro
print(G2)

Ft = F1 + (F2-1)/G1 + (F3-1)/(G1*G2) + (F4-1)/(G1*G2*G3)

print(Ft)

print('$$Ft = {0.real:4.3} $$' .format(Ft))

NFt = 10*np.log10(Ft)
print('$$NFt = {0.real:4.3} dB$$' .format(NFt))
# Out:
# 984.0371383405493
# 1.4524214953529473
# $$Ft = 1.45 $$
# $$NFt = 1.62 dB$$

# %%
### 1 

Qm1o = ((ropt/rg) -1)**0.5

print(Qm1o)

C1o = 1/(Qm1o * wo * rg)

print( '$$C_1o = {0.real:4.3} pF$$' .format(C1o/1e-12))

C1op = C1o /(1 + 1/Qm1o**2)

C1ot = C1op + c11

L1o = 1/(C1ot*wo**2)

print( '$$L_1o = {0.real:4.3} nHy$$' .format(L1o/1e-9))


Qc1o = 1/( (1/Qo1)+(wo*L1o*2/r11))

print( '$$Q_co = {:4.3}$$' .format(Qc1o))
# Out:
# 0.7745966692414834
# $$C_1o = 4.57 pF$$
# $$L_1o = 8.98 nHy$$
# $$Q_co = 2.39$$

# %%
F2o = 10**(NFmcr/10)



Fto = F1 + (F2o-1)/G1 + (F3-1)/(G1*G2) + (F4-1)/(G1*G2*G3)


NFto = 10*np.log10(Fto)

print('$$Fto = {0.real:4.3} $$' .format(Fto))

print('$$NFto = {0.real:4.3} dB$$' .format(NFto))
# Out:
# $$Fto = 1.29 $$
# $$NFto = 1.12 dB$$

# %%
print('$$SNRo = {0.real:4.4} $$' .format(SNRo))

Ni = kb * Te * Beq


print('$$Ni = {0.real:4.3} pW$$' .format(Ni/1e-12))

SNRi = SNRo/Fto

print('$$SNRi = {0.real:4.3} $$' .format(SNRi))

Si = SNRi*Ni

print('$$Si = {0.real:4.3} pW$$' .format(Si/1e-12))
# Out:
# $$SNRo = 100.0 $$
# $$Ni = 0.276 pW$$
# $$SNRi = 77.3 $$
# $$Si = 21.3 pW$$

# %%
Fimg =  Frf - 2*Fif

A1 = 1/(1+(Qc1o*(Fimg/Frf-Frf/Fimg))**2 )**0.5
A2 = 1/(1+(Qc2* (Fimg/Frf-Frf/Fimg))**2 )**0.5
A3 = 1/(1+(Qc3* (Fimg/Frf-Frf/Fimg))**2 )**0.5

Abt = 1/(1+((Fimg-Frf)/(BWbt/2))**(2*Nbt) )**0.5

Att = A1 

AttdB = 20*np.log10(Att)

print('$$Att = {0.real:4.3} $$' .format(Att))

print('$$Att = {0.real:4.5} dB$$' .format(AttdB))
# Out:
# $$Att = 0.777 $$
# $$Att = -2.1951 dB$$

# %%
BFR360 = Network('spice/F43V03M0.S2P')

freq = Frequency(800,900,11,'mhz')

fo = 900e6
wo = 2*np.pi*fo

print('Parametros S:')

printS(BFR360['900mhz'].s[0])
print(' ')

print('Parametros Y:')
Y900 = BFR360['900mhz'].y[0]


printY(Y900)

Yopt = 1/80
print( 'ropt= {0.real:4.2F}' .format(1/(Yopt.real) ))
print( 'copt= {0.real:4.2E}' .format(  Yopt.imag/wo) )
# Out:
# Parametros S:
# s11= 0.619  -89.30
# s12= 0.106  50.30
# s21= 6.138  118.40
# s22= 0.629  -45.70
#
# Parametros Y:
# y11= 4.01E-03  9.56E-03j
# y12= -1.97E-05  -1.82E-03j
# y21= 9.72E-02  -4.03E-02j
# y22= 8.15E-05  2.66E-03j
#
# r11= 249.60
# c11= 1.69E-12
# gm = 0.11
# gr = 0.0018
# r22= 12266.76
# c22= 4.70E-13
# ropt= 80.00
# copt= 0.00E+00

# %%
fo = 900e6
wo= 2*np.pi*fo

Cp  = 0.2e-12
Cu  = 0.4e-12
Co  = 0.5e-12

Icq  = 1e-3
vt   = 26e-3
Beta = 100
gm  = 100e-3

# Parametros del transistor
y11 =    4.0e-3  +10.0e-3j
y12 =            - 0.20e-3j
y21 =   40.0e-3  - 1e-3j
y22 =    0.1e-3  + 2.0e-3j


yt  = np.matrix([[y11, y12],[ y21, y22]])

Linvill(yt)

print( 'r11= {0.real:4.2F}' .format(1/y11.real) )
print( 'c11= {0.real:4.2E}' .format(y11.imag/wo) )


print( 'gm = {0.real:4.2F}' .format(abs(y21)) )
print( 'gr = {0.real:4.4F}' .format(abs(y12)) )

print( 'r22= {0.real:4.2F}' .format(1/y22.real) )
print( 'c22= {0.real:4.2E}' .format(y22.imag/wo) )
# Out:
# ###############  LINVILL   #####################
# coeficiente de linvill C= 9.75
# Es potencialmente inestable
# r11= 250.00
# c11= 1.77E-12
# gm = 0.04
# gr = 0.0002
# r22= 10000.00
# c22= 3.54E-13

# %%
## MTEQ
yg = (yt[0,0].real-yt[0,0].imag*1j)

yl= (yt[1,1].real-yt[1,1].imag*1j)

K = Stern(yg, yl, yt)


## Cargando la salida
yg = (yt[0,0].real-yt[0,0].imag*1j)

yl= (1/1000-yt[1,1].imag*1j)

K = Stern(yg, yl, yt)



## Cargando la salida y Zopt
Yopt = 1/80
yg = (Yopt.real-yt[0,0].imag*1j)

yl= (1/1000-yt[1,1].imag*1j)

K = Stern(yg, yl, yt)
# Out:
# $|y_12 \cdot y_21)+\Re (y_12 \cdot y_21) = 7.80E-06
# ###############  STERN   #####################
# coeficiente de stern K= 0.41
# Inestable
# $|y_12 \cdot y_21)+\Re (y_12 \cdot y_21) = 7.80E-06
# ###############  STERN   #####################
# coeficiente de stern K= 2.26
# Estable
# $|y_12 \cdot y_21)+\Re (y_12 \cdot y_21) = 7.80E-06
# ###############  STERN   #####################
# coeficiente de stern K= 4.65
# Estable
