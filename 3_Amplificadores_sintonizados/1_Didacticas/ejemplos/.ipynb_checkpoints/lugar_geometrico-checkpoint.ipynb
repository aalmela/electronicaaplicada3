# %%
import myplot as myp
import numpy as np
import matplotlib.pyplot as plt

y11= 0.0011+  (0.0014)j
y12= -0.0000+  (-0.0002)j
y21= 0.1422+  (-0.0063)j
y22= 0.0001+  (0.0004)j

def Y1(wn):
    return 0.0011+(1j*w)+1/(1j*w)

def Y2(wn):
    return 1+(1j*w)+1/(1j*w)

y12 = 1 * np.exp(1j*220/180*np.pi)

y21 = 10 * np.exp(1j*0/180*np.pi)

print(y12,y21)

def Y2(wn):
    return 1+(1j*w)+1/(1j*w)

def Yin(wn):
    return Y1(w)-(y12*y21)/Y2(w)


w    =  np.linspace(0.1,10,1000)
# Out:
# (-0.766044443118978-0.6427876096865393j) (10+0j)

# %%
plt.plot( Y1(w).real, Y1(w).imag)
plt.grid()

# %%
plt.plot( ((y12*y21)/Y2(w)).real, ((y12*y21)/Y2(w)).imag)
plt.grid()
plt.show()

# %%
plt.plot( (Yin(w)).real, (Yin(w)).imag)
plt.grid()
plt.show()
