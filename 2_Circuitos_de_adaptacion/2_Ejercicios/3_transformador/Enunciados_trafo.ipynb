# %% [markdown]
# # Ejercicio 1:  Transformador
#
# ![1](figg/eje2_a.png)
#
# El siguiente circuito corresponde a un adaptador de impedancias realizado con un trasformador, cuyo  $Q_{oL} = \infty$  , y un capacitor de $ C_1$ conectado en paralelo con el primario, cuyas pérdidas se suponen despreciables.
#
# La impedancia interna de la fuente es de $y_g= (0.005+0.00025) S$ a $f = 200MHz$ y su potencia disponible es de $P_{disp} = 10 nW$.
#
# La resistencia de carga es de $R_L = 1000 \Omega$.
#
#
# Nota: en SPICE la sentencia ``k1 L1 L2 1'' indica que el transformador tiene $K = 1$ (acople máximo).
#
# Para $Q_c= 20$ a $200MHz$
#
# 1. $C$
#
# 2. $Lp$
#
# 3. $Ls$
#
# 4. Relación de vueltas del transformador.
#
# 5. Tensión en el primario (bobinado conectado a la fuente)
#
# 6. Tensión del secundario (bobinado conectado a la carga)
#
# 7. Potencia sobre $R_L$.

# %% [markdown]
# # Ejercicio  2: Auto-transformador
#
# El siguiente circuito corresponde a un adaptador de impedancias realizado con un auto-trasformador, cuyo  $Q_{oL} = \infty$ a la frecuencia de trabajo, y un capacitor de $C_1$ conectado en paralelo con el primario, cuyas pérdidas $Q_{oC} = \infty$.
#
# ![11-cuatrocientos](figg/eje3b.png)
#
# La admitancia interna de la fuente es de $y_g(100MHz)= (0.0134+0.001267j) S$ y la corriente que entrega es $i_{g}(100MHz) = 1 \mu A$.
#
# La resistencia de carga es de $R_L = 1500 \Omega$.
#
#
# Nota: en SPICE la sentencia "k1 L1 L2 1" indica que el transformador tiene $K = 1$ (acople máximo).
#
#
# Para máxima transferencia de energía a un $Q_c = 20$, se busca que $R_L' = r_g$.
#
#
#
# Para $Q_c= 20$ a $100MHz$:
#
# 1. $C_1$
#
# 2. $L_1$
#
# 3. $L_2$
#
#
# 4. La relación de vueltas del transformador.
#
#
# 5. Tensión en el primario
#
# 6. Tensión en el secundario
#
# 7. $P(R_L)$

# %% [markdown]
# # Ejercicio 3: Divisor Capacitivo
#
# Se desea conectar una carga de $R=100\Omega$ a un transistor.
# La admitancia de salida del transistor es $g_o = \frac{1}{8100\Omega}$ y $b_o = 2 \pi fo 10 pF$ a $f_o = 4 MHz$. Suponga que la fuente de corriente es de $i_o = 10uA$.
# Se desea un ancho de banda de $BW = 200KHz$ a $f_o = 4 MHz$.
#
# ![11-cuatrocientos](fig/eje4.png)
#
#
# Asumir que todas las perdías corresponden a el inductor con un $Q_o = 100$.
#
# Para máxima transferencia de energía a Qcte a $F_o =4MHz$.
#
# 1. $Q_c$
#
# 2. $L$
#
# 3. $C_1$
#
# 4. $C_2$
#
# 5. Potencia disponible del transistor.
#
# 6. Potencia en la carga.

# %% [markdown]
# # Ejercicio 4 Divisor Capacitivo
#
#
# Se desea conectar una carga de $R=100\Omega$ a un transistor, empleando un divisor capacitivo, como se muestra en la figura.
#
#
# ![](fig/eje3b.png)
#
# La resistencia de salida del transistor es $r_o = 6000\Omega$ a $f_o = 10MHz$.
#
# Suponga que la fuente de corriente es de $i_o = 10uA$.
#
# Se desea un ancho de banda de $BW = 300 KHz$ a $f_o = 10 MHz$.
#
# Asumir que todas las perdías corresponden al inductor con un $Q_o = 100$.
#
#
# 1. $C$ (capacitor de sintonia) y $L$ para máxima transferencia de energía a Qcte a $F_o =10\,MHz$.
# 2. $C_1$ y $C_2$ para máxima transferencia de energía a Qcte a $F_o = 10\,MHz$ realizando el calculo sin emplear simplificaciones.
# 3. Verificar si es posible emplear simplificaciones y comparar resultados.
