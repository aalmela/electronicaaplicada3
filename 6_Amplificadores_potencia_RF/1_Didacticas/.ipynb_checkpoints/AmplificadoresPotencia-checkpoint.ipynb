# %% [markdown]
# # Amplificadores de potencia de RF
#
# En los amplificadores de potencia (AP) la clase da una amplia indicación de las características y el rendimiento de un amplificador.
# Las clases están relacionadas con el período de tiempo en que el dispositivo amplificador activo está pasando corriente, expresado como una fracción del período de una forma de onda de señal aplicada a la entrada.
#
# Un amplificador de clase A está conduciendo a través de todo el período de la señal; la clase B sólo durante la mitad del período de entrada, la clase C durante mucho menos de la mitad del período de entrada.
# Un amplificador de clase D hace funcionar su dispositivo de salida de forma conmutada; la fracción del tiempo que el dispositivo está conduciendo se ajusta de forma que se obtiene una salida de modulación de anchura de pulso de la etapa.
# Se definen clases de letras adicionales para los amplificadores con fines especiales, con elementos activos adicionales o mejoras particulares de la fuente de alimentación; a veces un fabricante utiliza un nuevo símbolo de letras para promover su diseño patentado.
#
# Los AP de RF lineales, es decir fundamentalmente aquellos denominados clase A y B (push-pull), son poco eficiencites.
# En estos se incluyen a menudo circuitos sintonizados o filtros pasa bajo para asegurar la supresión adecuada de armónicosos, pero no son componentes integrales de estos amplificadores.
# Como el ancho de banda de un señal de RF suele ser una fracción pequeña de la frecuencia de portadora y del ancho de banda del AP, una parte de las señales no deseadas a la salida del amplificador de potencia pueden ser originadas por alinealidades en los circuitos.
#
# La falta de linealidad del amplificador produce dos tipos de señales no deseadas, Productos Armónicos y intermodulación (en inglés intermodulation, IMD abreviado).
#
# La IMD es la modulación de amplitud no deseada de señales, con dos o más frecuencias diferentes, producida en sistemas no lineales.
# La intermodulación entre cada componente de frecuencia formará señales adicionales en frecuencias que no son, en general, armónicos (múltiplos enteros) de cualquiera de ellas, sino a menudo las frecuencias suma y diferencia de las frecuencias originales.
# Los IMD son identificados con el orden que los conforman (tercero, quinto, etc). Cerca de la frecuencia de portadora causan distorsión en la señal recibida e interferencias de canal adyacente o ambas.
#
# A otras señales no deseadas tales como oscilaciones subarmónicas, señales parásitas o productos indeseados de mezcladores, se los llama productos espurios.
#
# En un amplificador de potencia de RF, las armónicas y alguno de los productos espurios se pueden eliminar con filtros, sin embargo los IMD generados deben ser de un nivel aceptablemente bajo debido a que algunos de ellos se encuentran muy próximos a la señal deseada.
#
# Las armónicas producidas por la no linealidad del dispositivo se filtran a través del circuito sintonizado paralelo.
# Cualquier componente de frecuencia de portadora de $i(\theta)$ fluye a través de la resistencia de carga R (suponiendo una sintonización adecuada del circuito paralelo sintonizado y efectos insignificantes provenientes del  choque y del Cb ).

# %% [markdown]
# ## Sintetizando Amplificadores de Potencia de RF
# (AN-282A)
#
# Las técnicas más populares de diseño de pequeñas señales de RF son:
# 1. el uso de parámetros de cuadripolos
# 2. el uso de algún tipo de circuito equivalente
#
# Los primeros intentos de adaptar estas técnicas al diseño del amplificador de potencia dieron lugar a malos resultados y a la frustración.
# A mediados de los años 60, Motorola fue pionera en el concepto de diseño de amplificadores de potencia de estado sólido mediante el uso de grandes impedancias de entrada y salida de transistores de señal.
# Desde entonces, este sistema ha logrado una aceptación casi universal por parte de los fabricantes de equipos de comunicaciones de estado sólido.
# Proporciona un procedimiento de diseño sistemático para reemplazar lo que solía ser un proceso de prueba y error.
#
# ### Limitaciones de los parametros de pequeña señal
#
# Mediante un ejemplo se intentara mostrar los inconvenientes de tratar de adaptar los parámetros de la pequeña señal al diseño del amplificador de potencia, empleando el transistor 2N3948.
# Se hizo una comparación del rendimiento del 2N3948 que funciona a $f_o =300 MHz$ como un amplificador de pequeña señal de clase A y como un amplificador de potencia de clase C con una potencia de salida de 1 W.
# En la tabla 1 se muestran los resultados de esta comparación.
#
# |  | Clase A<br>Diseño pequeña señal<br>$V_{CE}=15 Vdc$;$I_c=80mA$<br>$300 MHz$ | Clase C<br>Amplificador de Potencia<br>$V_{CE}=13.6 Vdc$;<br>$P_o =1W$ |
# |-|:-:|:-:|
# | Resistencia de entrada | $9 \Omega$ | $38 \Omega$ |
# | Reactancia de entrada | $12nHy$ | $21pF$ |
# | Salida de transistor | $199 \Omega$ | $92 \Omega$ |
# | Capacidad de salida | $4.6 pF$ | $5.0 pF$ |
# | $G_{PE}$ | $12.4 dB$ | $8.2 dB$ |
#
# Tabla: Modelo de pequeña a gran señal, la compleja impedancia de entrada del 2N3948 experimenta un cambio considerable en su magnitud, cambiando de reactancia inductiva a capacitiva.
# Obsérvese también que las resistencias de salida del transistor y las ganancias de potencia son considerablemente diferentes para los dos modos de funcionamiento.
# Este ejemplo muestra claramente las inexactitudes que darían lugar a un diseño de amplificador de potencia basado en los parámetros de pequeña señal de este dispositivo.
#
#
# ### IMPORTANCIA DE LOS PARÁMETROS DE LA GRAN SEÑAL
#
# La teoría de la red para el diseño de amplificadores de potencia es bien conocida pero no es útil, a menos que el diseñador tenga datos válidos de impedancia de entrada y salida para el transistor.
# El método de diseño descrito en este desarrollo depende principalmente de la medición directa de estos parámetros para su uso en ecuaciones de síntesis de redes.
# Los datos de impedancia de gran señal, junto con los datos de potencia de salida y de ganancia, proporcionan al diseñador la información necesaria para diseñar sus redes de amplificadores y para predecir el rendimiento que debe alcanzarse cuando se complete el diseño.
# Es importante comprender claramente las condiciones de prueba y el método de presentación de los datos de la impedancia de la gran señal.
#
# ### Condiciones
#
# Los términos "impedancia de entrada de gran señal" e "impedancia de salida de gran señal" se refieren a la impedancia terminal real del transistor cuando funciona en un amplificador adaptado al nivel de salida de potencia de RF y al voltaje de suministro de continua deseados.
#
# Adaptado se define como la condición en la que las redes de entrada y salida del amplificador de prueba proporcionan una coincidencia conjugada con el transistor, de tal manera que la impedancia de entrada y salida del amplificador es de $50 \Omega$.
#
# Las impedancias de gran señal no debe confundirse con la de pequeña señal, los parámetros del cuadripolo normalmente se miden a niveles de bajas señal con sesgo de clase A y el transistor (o IC) conectado directamente con cortocircuito, circuito abierto o  $50 \Omega$.
#
# La mayoría de los datos que aparecen en las hojas de datos de los transistores de potencia de RF de Motorola se miden como amplificadores de Clase C en configuración de emisor comun, ya que esta condición cubre la mayoría de las aplicaciones de los dispositivos.
#
# Como excepción de los transistores caracterizados para amplificación de potencia lineal en clase B.
# Ejemplos de tales transistores son la serie Motorola 2N5941-2.
# Dado que estos transistores están diseñados específicamente para el amplificación lineal, sus impedancias de gran señal se midieron en un circuito de prueba de amplificador de potencia lineal con una señal de prueba de dos tonos en lugar de la señal convencional de una sola frecuencia.
# Para más información sobre estos transistores véase la hoja de datos de Motorola 2N5941-2.
#
# Gran parte de la información de las hojas de datos de los dispositivos se presenta en forma equivalente  de resistencia y capacitancia en paralelo.
# Los datos también pueden presentarse en forma equivalente en serie.
#
# ![1-cuatrocientos](fig/RIN_2N5849.png)
#
# ![2-cuatrocientos](fig/CIN_2N5849.png)
#
# ![3-cuatrocientos](fig/COT_2N5849.png)
#
# ### DISEÑO DEL AMPLIFICADOR
# Después de seleccionar un transistor con las capacidades de rendimiento requeridas, el siguiente paso en el diseño de un amplificador de potencia es determinar las impedancias de entrada y salida de grandes señales del transistor.
#
# Cuando se utilizan dispositivos para los que se dispone de datos, este paso no implica más que la lectura de los complejos valores de impedancia de la hoja de datos.
# Si sólo se da la capacitancia de salida en la hoja de datos, la resistencia de carga del colector puede calcularse de la manera descrita en la sección Resistencia de carga del colector de esta nota.
#
# Una vez más, se advierte al diseñador que debe determinar cuidadosamente si las curvas de impedancia de la hoja de datos están en forma equivalente en paralelo o en serie, y que debe utilizar los datos en consecuencia.
# Si los datos no están disponibles, una sección posterior de esta nota contiene información sobre la medición de la impedancia de gran señal.
#
# Una vez determinadas las impedancias de gran señal, el diseñador selecciona una configuración de red adecuada y procede a su síntesis de red.
#
# El propósito principal de esta nota es describir el concepto de impedancia de gran señal. Por consiguiente, la selección y síntesis de la red están fuera del alcance de esta discusión. Para ejemplos específicos de diseño de transmisores que utilizan este concepto, se remite al lector a la siguiente Nota de Aplicación de Motorola: AN-548A y AN-721.
#
# ### RESISTENCIA DE LA CARGA DEL COLECTOR
#
# Los datos de impedancia de gran señal en HF y VHF han sido publicados en su mayor parte por Motorola sin información de resistencia de carga del colector.
# La razón es que la resistencia de carga puede ser calculada fácilmente. Las condiciones necesarias para obtener esta derivación de la resistencia de carga se discutirán ahora.
#
# Si se hacen ciertas suposiciones simplificadoras, el voltaje teórico del colector de un amplificador de potencia con una red de salida sintonizada es una onda sinusoidal que oscila de cero a $2 V_{CC}$.
# donde $V_{CC}$ es el voltaje de suministro del colector de la fuente DC.
#
# Estas suposiciones incluyen:
# 1.  $V_{CE}(sat)$ es igual a cero.
# 2.  La red de salida tiene suficiente $Q_C$ para producir un voltaje de onda sinusoidal independientemente del ángulo de conducción del transistor.
# 3.  La caída de voltaje en el sistema de alimentación del colector de CC es cero.
# 4.  La impedancia de carga del colector en todos los armónicos de la frecuencia de operación es cero.
#
# Obviamente, ninguno de los supuestos anteriores es cierto, y las discrepancias más graves probablemente se derivan de los supuestos 1 y 4.
#
# Supongamos por un momento que esta condición teórica existe.
# La resistencia de carga del colector equivalente en paralelo, $R_L'$, se convierte entonces en una función de la potencia de salida de RF deseada y de la tensión $V_{CC}$ únicamente.
# La expresión para $R_L'$ dada en la ecuación se deduce fácilmente
#
# $$R_L' =\frac{V_{CC}^2}{2 P_o}$$
#
# Por lo tanto, la  impedancia compleja de carga del colector para el diseño de amplificador sería el conjugado de la capacitancia de salida equivalente en paralelo y la resistencia de carga del colector calculada con la Ecuación.
#
# La Figura proporciona una solución gráfica a la Ecuación para los cuatro populares niveles de suministro de $V_{cc}$ de $12.5 V$, $13.6 V$, $24 V$ y $28 V$.
#
#
# ![4-cuatrocientos](fig/RF_Cout_Watt.png)
#
#
#
# A pesar de las suposiciones necesarias, la experiencia con el componente concentrados de HF y VHF, los amplificadores de potencia con tensiones de alimentación de $7$ a $30 Vdc$ y niveles de salida de potencia de unas pocas décimas de vatio a $300 W$ han demostrado que el uso de la Ecuación 1 para calcular $R_L'$ para la síntesis de redes da buenos resultados.
#
# Es decir, los tipos de redes de salida de colectores de componentes concentrados (lumped) de HF y VHF que han demostrado ser los mejores desde el punto de vista de la adaptación de la impedancia adecuada con bajas pérdidas y una sintonización suave, generalmente tienen un rango de adaptación y ajuste suficiente para compensar cualquier error asociado con la Ecuación 1.
#
# Por supuesto, si el $V_{CE}(sat)$ del transistor se conoce con precisión para la frecuencia de funcionamiento y las oscilaciones de corriente del colector previstas en un amplificador determinado, la Ecuación 1 se modifica fácilmente como sigue
#
# $$R_L' =\frac{(V_{CC}-V_{CE}(sat))^2}{2 P_o}$$

# %% [markdown]
# ##  MOSFETs de potencia versus transistores bipolares
# (AN-860)
#
# Varios fabricantes han introducido recientemente FETs de potencia para aplicaciones de amplificación de RF.
# Se dispone de dispositivos con capacidad de salida de 100 W para frecuencias de VHF y se fabrican unidades más pequeñas para el funcionamiento en UHF.
# Todos son dispositivos de modo de mejora, lo que significa que la puerta debe estar sesgada con voltaje positivo (canal N) con respecto a la fuente para "encenderla".
# Los primeros diseños fueron llamados V-MOSFETs, donde el canal está en una ranura en V.
# La ranura en V debe ser grabada con un proceso especial, y el material de silicio debe tener una orientación de cristal diferente del material normalmente utilizado para los transistores bipolares. La dificultad del proceso de grabado en la producción ha llevado al desarrollo de otros tipos de estructuras de canal como HEX y T, que siguen siendo estructuras de canal vertical, pero la ranura en V se elimina, y la puerta está en una superficie recta.
#
# Así pues, para una periferia de puerta igual, se requiere más espacio en la superficie.
#
# Los fabricantes japoneses parecen favorecer las geometrías con canales horizontales.
# Son similares a los pequeños MOSFETs de señal con varios de ellos paralelos en un chip.
# Esta técnica representa un uso aún más derrochador de la superficie del dado que el HEX o el TMOS.
# Típicamente un FET de potencia requiere de 50 a 100 por ciento más área del dado que un transistor bipolar para un rendimiento de salida de potencia igual.
# En el caso del TMOS, el número es de aproximadamente el 50 por ciento.
# Esto se debe principalmente al mayor voltaje de saturación, pero la geometría también da un 30 por ciento menos de periferia de la puerta que el área base disponible en bipolar.
# Dado que el precio de un dispositivo de estado sólido es una función del tamaño del dado, obtenemos menos vatios por dólar.
# Esto es completamente opuesto a lo que la industria ha tratado de hacer en los últimos años con los transistores bipolares. Por lo tanto, uno puede preguntarse: ¿Qué es mejor, si acaso, con los FET de potencia si podemos conseguir un transistor bipolar con una potencia igual por menos de la mitad del precio?
# Aquí es donde llegamos al propósito de este artículo, que es discutir las características del FET y el dispositivo bipolar. Ambos tienen la misma geometría básica, pero con algunos cambios de máscara, uno fue procesado como un MOSFET y el otro como bipolar.

# %% [markdown]
# ## Amplificador de Potencia Lineal Clase A
#
# https://www.highfrequencyelectronics.com/Aug06/0806_Ali.pdf
#
# https://cdn.macom.com/datasheets/MRF173.pdf
#
#
# https://cdn.macom.com/datasheets/MRF1000MB.pdf
#
#
# El circuito de un amplificador de potencia en clase A con emisor común es semejante al del amplificador analógico en señal débil.
# En una aplicación de potencia la resistencia de la carga es por lo general lo suficientemente pequeña para que los efectos de la resistencia y reactancia  de salida del dispositivo sean insignificantes.
#
# Como el punto Q, es decir, $I_{CQ}$, se selecciona para conservar siempre al transistor en su región activa, el dispositivo equivale a una fuente de corriente.
#
# El circuito sintonizado paralelo o el filtro equivalente no es una parte necesaria de un amplificador en Clase A.
# Sin embargo, como ningún dispositivo es perfectamente lineal, se incluye a menudo un circuito sintonizado o un filtro para evitar que las corrientes armónicas alcancen la carga.
#
# En el amplificador de la figura, la señal de excitación y la polarización aplicadas se supone que producen la corriente de colector $i_C(\theta)$ mostrada en la figura (sin tener en cuenta distorsiones de la señal):
#
# $$i_C(\theta)=I_{CQ} − i_{cm} sen(\theta)$$
#
# Las componentes armónicas de $i_C(\theta)$ se omiten en la ecuación anterior porque generalmente tienen poco efecto sobre la potencia o eficiencia de un amplificador clase A.
# Las componentes de corriente continua y corriente alterna de $i_C(\theta)$ deben fluir a través del choque de RF y por el capacitor de bloqueo $C_b$, respectivamente y por lo tanto, convertirse en la corriente de entrada $I_{dc}=I_{CQ}$ y en la de salida $i_o(\theta)=I_{cm} sen(\theta)$, respectivamente.
# Las corrientes
#
# $$v_o(\theta) = I_{cm} R sen(\theta)$$
#
# Como la operación en fuente de corriente del dispositivo puede mantenerse solo cuando $v_C(\theta)$ es positivo, es menester limitar el tensión de salida Vom a valores menores que VCC2. (Realmente, el valor máximo Vom debe ser ligeramente menor que VCC, debido a los efectos de saturación que se analizarán luego).
#
# Como la corriente de colector $i_C(\theta)$ debe ser similarmente positiva, $I_{dc} = I_{CQ}$ se hace por lo común igual o ligeramente mayor que la corriente de salida pico $I_{om}=\frac{V_{om}}{R} \le \frac{VCC}{R}$.
#
# Consecuentemente la potencia de continua es:
#
# $$P_{dc} = V_{CC} I_{dc}$$
#
# de salida
#
# $$P_o = \frac{V_{om}^2}{2 R} \le \frac{V_{CC}^2}{2 R}$$
#
# donde la eficiencia
#
# $$n = \frac{P_o}{P_{dc}} = \frac{V_{om}^2}{2 V_{CC}^2} \le \frac{1}{2}$$
#
#
# La potencia $P_d$ disipada en el transistor es la diferencia entre Pi y Po.
# Las relaciones de potencia y eficiencia al tensión de salida se muestran a continuación.
# Un buen diseño supondrá el valor máximo de $P_d = P_{dc}$ para permitir condiciones de no señal o señal reducida.
#
# La observación de las formas de onda se muestra que cuando el amplificador de potencia clase A esta entregando su salida máxima, la tensión y corriente de colector máximos son $v_{C,max} = 2 V_{CC}$, $i_{C,max} = 2 I_{CQ}= \frac{2 V_{CC}}{R}$.
#
# La capacidad de salida de potencia normalizada pico, por lo tanto:
#
# $$\frac{P_{o,max}}{P_o} = \frac{P_{o,max}}{v_{c,max} i_{c,max}} = \frac{\frac{V_{CC}^2}{2 R}}{(2 V_{CC})(2 \frac{V_{CC}}{R})} = \frac{1}{8}$$
#
# Los amplificadores de potencia de RF en clase A se usan mas comúnmente como amplificadores de excitación en bajo nivel.
# En estas aplicaciones la potencia consumida por el amplificador clase A es una porción relativamente pequeña de la potencia total del transmisor.
# Los amplificadores de potencia clase A se utilizan también en frecuencias de microondas, donde resulta difícil emplear otras clases de amplificación.

# %%
import numpy as np
import matplotlib.pyplot as plt

import scipy                  # http://scipy.org/
from scipy.fftpack import fft, fftfreq
from time import time



# %matplotlib inline

params = {'legend.fontsize': 12,
          'figure.figsize': (6, 2),
         'axes.labelsize': 12,
         'axes.titlesize': 12,
         'xtick.labelsize':12,
         'ytick.labelsize':12}
plt.rcParams.update(params)

# Señal
VCC  =10

icq  = 1
icm  = .4
R    = 10



# defino el sampleo
n  = 100
# vector de tiempo 
th  = 2*np.pi*np.linspace(0, 1, num=n)


# modulante
ic   = icq - icm*(np.sin(th) )
io   = icm*(np.sin(th) )
vo   = R*io 
vce  = VCC+vo

ax = plt.plot(th, ic)
plt.ylabel('$i_c$ [A]')
plt.xlabel('$\\theta$')
plt.ylim(-icq*0.1, icq*1.5)
plt.grid()
plt.show()

plt.plot(th, io)
plt.ylabel('$i_o$ [A]')
plt.xlabel('$\\theta$')
#plt.ylim(0, icq*1.5)
plt.grid()
plt.show()

plt.plot(th, vo)
plt.ylabel('$i_o$ [V]')
plt.xlabel('$\\theta$')
#plt.ylim(0, icq*1.5)
plt.grid()
plt.show()

plt.plot(th, vce)
plt.ylabel('$v_{ce}$ [V]')
plt.xlabel('${\\theta}$')
plt.ylim(0, VCC*1.5)
plt.grid()
plt.show()

# %% [markdown]
# ## Ejemplo amplificador Clase A empleando el transitor bipolar MRF448A
#
# https://cdn.macom.com/datasheets/MRF448A.pdf
#
# https://www.highfrequencyelectronics.com/Aug06/0806_Ali.pdf
#
#
# En el diseño de los amplificadores de microondas de banda ancha, hay dos técnicas que se utilizan típicamente para lograr una ganancia plana en la banda de frecuencias de interés.
# La primera técnica se realiza mediante una desadaptación selectiva en frecuencias más bajas de la banda donde la ganancia de potencia es significativamente mayor.
# Esto puede lograrse degradando la VSWR en la entrada o la salida en el borde de la banda de baja frecuencia.  La segunda técnica se lleva a cabo añadiendo redes de compensación disipativas.
#
# La red de adaptación de entrada se diseña primero para lograr mínimos en toda la banda, y la nivelación de ganancia requerida se hace entonces añadiendo el circuito de compensación de pérdidas.
# Esta red es una red de resistencia constante y debe tener una característica de pérdida de inserción por balanceo para compensar la característica de ganancia por balanceo inherente del transistor de RF en toda la banda de frecuencias.
#
# La segunda técnica se ha implementado para diseñar un amplificador de potencia lineal de clase A que funcione dentro de la banda de frecuencias de 225MHz a 400 MHz y que suministre 20 dBm de potencia de salida con más de 12 dB de ganancia de potencia en esta banda de comunicaciones.  La estrategia de diseño se presentará de manera sistemática en este texto.
#
#
# ### Caracterización del dispositivo
#
# El dispositivo de potencia de RF disponible es el transistor V575.
# La caracterización del dispositivo incluye la selección del punto de polarización óptimo y la medición de los parámetros S en este punto. Dado que se supone que el funcionamiento es lineal, la técnica de los parámetros S es una herramienta poderosa para modelar el comportamiento del transistor de microondas seleccionado.
#
# Selección del punto de polarización
#
# La configuración de la prueba utilizada para seleccionar el punto de sesgo óptimo que garantice un funcionamiento seguro con una buena linealidad se muestra en la figura 1.
# El transistor está montado en un sistema de banda ancha de 50 ohmios con un medio para ajustar fácilmente el voltaje y la corriente de polarización. L
# a potencia de salida del generador de señales se ajusta de manera que la potencia de salida del transistor se mantenga constante.
# El nivel de la potencia del segundo armónico en relación con la potencia fundamental se mide con la ayuda de un analizador de espectro y se representa gráficamente a medida que se varían el voltaje y la corriente de polarización. Este proceso se repite en varias frecuencias de la banda para comprobar el nivel de distorsión en todo el ancho de banda operativo.
# No se intentó hacer coincidir el dispositivo con la impedancia de carga óptima y, por esta razón, los contornos de la figura 2 se muestran para una potencia de salida de +15 dBm y una frecuencia de prueba de 300MHz. Como la ganancia es muy baja, intentar entregar más potencia en una carga sin igual sólo hará que el transistor sea impulsado con excesiva dureza. Esto, a su vez, generará no linealidades dentro del transistor que pueden dar una imagen errónea de sus características normales de funcionamiento. Dado que la distorsión en un transistor es también una función de la impedancia de la carga del colector y del nivel de potencia, los contornos de distorsión de la figura 2 no deben considerarse absolutos, sino más bien como una buena aproximación de primer orden de la sensibilidad de distorsión del dispositivo al punto de reposo. El punto de sesgo seleccionado fue VCE= 15 V, y IC= 60 mA
#
#
# Medición del parámetro S
#
# Después de seleccionar el punto de polarización óptimo, los parámetros S del dispositivo deben ser medidos en este punto de polarización.
# Para hacer esta medición, primero se diseñó un aparato de transistores que se muestra en la figura 3.
# El aparato se construyó utilizando una placa de fibra de vidrio PTFE de alta calidad que tiene pérdidas mínimas y que puede utilizarse en frecuencias de hasta varios gigahercios.
# Este aparato de prueba también consiste en dos líneas de microtiras de 50 ohmios y conectores tipo SMA para la alimentación de la señal.
#
# El dispositivo, que tiene el paquete hermético de líneas de tiras, fue montado entre las dos líneas de 50 ohmios con su caja soldada al lado del suelo (parte inferior) de la placa para asegurar una buena transferencia de calor. Las tes de polarización mostradas en esta figura tienen la función de aislar el circuito de polarización de CC de la señal de RF y también para bloquear la corriente CC del analizador de red. La Figura 5 presenta un gráfico de los parámetros S21 y S12 medidos, mientras que la Figura 6 muestra los parámetros S11 y S22 en un gráfico polar y también en el gráfico de Smith.
#
# Note en estos gráficos la caída de -6 dB/octava en S2 con la frecuencia y el valor relativamente alto de S11 que puede aumentar la complejidad de la red de equiparación de entradas. Los parámetros se grafican con un barrido de 100 a 500 MHz.
# El diseño de las redes pasivas de compensación de la ganancia de red del diplexor puede utilizarse para igualar la caída de la ganancia del amplificador con la frecuencia y, al mismo tiempo, mantener una baja VSWR. Estas redes de compensación son en realidad redes de resistencia constante que tienen una impedancia de entrada independiente de la frecuencia. En la figura 7[1] se muestra una configuración de tales redes.  Una posible realización de esta red se muestra en la Figura 8 y se conoce como la red de diplexores [2]. El circuito de la Figura 8 puede ser diseñado para lograr la resonancia en el borde de la banda superior fH. Esto asegurará que la pérdida de inserción de la red sea de 0 dB en fH. Puede demostrarse que el coeficiente de transferencia de tensión de la red de diplexores viene dado por [2]
#
#
# $$\frac{V_o(j\omega)}{V_i(j\omega)} = \frac{1}{1+j(\frac{\omega L_2}{R}+\frac{1}{\omega C_2 R})}$$
#
#
# $$\frac{V_o(j\omega)}{V_i(j\omega)} = \frac{1}{1+j Q(\frac{f}{f_o}-\frac{f_o}{f})}$$
#
#
# Las perdidas de inserción pueden ser expresadas como
#
# $$IL(f) = 20 LOG_{10}|\frac{V_o(j\omega)}{V_i(j\omega)}|$$
#
#
# $$IL(f) = 10 LOG_{10}|\frac{1}{1+ [Q(\frac{f}{f_o}-\frac{f_o}{f})]^2}|$$
#
# La pérdida de inserción de la red de diplexores deseada en fLis dada así b
#
# $$IL(f_d) = 10 LOG_{10}|\frac{1}{1+ [Q(\frac{f_d}{f_o}-\frac{f_o}{f_d})]^2}|$$
#
#
# Evaluating  equation  (3)  for  Qyields
#
# Los valores de los elementos de la red están dados por:
#
#
#
# Ejemplo de diseño de las redes de adaptación
#
# Usando el programa de computadora fueron sintetizados para lograr la máxima ganancia de energía y el mínimo de entrada y salida VSWR.
# La red de diplexores se diseñó primero analíticamente a partir de las ecuaciones presentadas en la sección 3 y luego se optimizó con Touchstone. Esta red se añadió a la entrada del amplificador para obtener una respuesta de ganancia plana en toda la banda.
# El archivo de circuito escrito para el diseño del amplificador se presenta en el Apéndice y el circuito optimizado del amplificador se muestra en la Figura 9. La Figura 10 muestra la ganancia de potencia simulada del circuito del amplificador sintetizado en toda la banda, mientras que la Figura 11 presenta la entrada y la salida VSWR trazada desde las ventanas de Touchstone.
#
# Diseño de la red de polarización de CC
#
#
#  La red de polarización debe ser capaz de mantener el punto de operación constante sobre las variaciones de temperatura y los parámetros del dispositivo. El circuito de polarización activa de la figura 12 fue seleccionado para esta tarea. El punto de polarización (15 V, 60 mA) puede mantenerse constante ajustando los valores de las resistencias R1, R2 y R3. Este circuito de polarización activo es en realidad un bucle de retroalimentación que detecta la corriente colectora del transistor de RF y ajusta la corriente de base para mantener fija la corriente colectora [3].
# Los valores de los elementos de la red se calculan de la siguiente manera.
# La resistencia R3 viene dada por: Touchstone, se encontró que el dispositivo era incondicionalmente estable (K>1) en toda la banda de operación.  Las redes de adaptación de entrada y salida

# %% [markdown]
# ### PROYECTO 1: Diseño de un Amplificador Clase A empleando MOSFET
#
#
#
# Veamos un diseño de Clase A.
# Es un PA de 5 Watt basado en el transistor MRF134 MOSFET.
# La siguiente figura muestra el circuito, que aunque parece completo, es sólo una sugerencia.
# Así que tendremos que ver las técnicas de estabilización de la polarización (tal vez, o la neutralización de las oscilaciones).
#
# ![5-cuatrocientos](fig/MRF134_circuito.png)
#
# En este ejemplo trataremos un amplificador de este tipo.
# Por supuesto, se pueden construir un par de amplificadores idénticos que pueden ser conducidos en paralelo, así como tambien rediseñar con varios FETS conectados en paralelo (cuidando las consideraciones de funcionamiento).
#
# El procedimiento para diseñar una clase A es el siguiente.
#
# 1. Obtener las impedancias de entrada y salida del FET.
#
# 2. Tensiones de entrada para polarización y exitación.
#
# 3. Encontrar la impedancia óptima de la carga de la línea de carga requerida para entregar la potencia deseada a la carga.
#
# 4. Diseñar redes de adaptación para que coincidan con $Z = 50 \Omega$ en la entrada y la salida.
#
# El primer paso es obtener la hoja de datos del MRF134.
#
# http://users.cecs.anu.edu.au/~Gerard.Borg/engn4545_borg/VHFPA/MRF134/mrf134DATA.pdf
#
#
# La siguiente figura muestra las impedancias del FET.
#
#
# ![5-cuatrocientos](fig/MRF137_Z.png)
#
#
# En general, las capacitancias están listadas en la hoja de datos, pero no las resistencias.
# FET la resistencia de la fuente de drenaje es la única de interés ya que puede ser bastante baja.
# Las capacitancias deben tratarse por separado (utilizando una red de adaptación para eliminar su efecto a alta frecuencia).
#
# La tabla de características eléctricas de la hoja de datos da la capacitancia de puerta a fuente, $C_{GS} = 20-50 pF$ y la capacitancia de drenaje a fuente $C_{DS} = 11-25 pF$.
# Estos tienen una incertidumbre bastante grande que deberá tenerse en cuenta al hacer el diseño.
# La capacitancia de drenaje a la puerta $C_{DG} = 4-5 pF$ y no es despreciable, especialmente porque será amplificada por el efecto Miller.
# También podría conducir a la inestabilidad y podría tener que ser neutralizada.
#
# La siguiente figura muestra las características IV del FET.
# Estas son las características de transferencia y salida del FET tomadas de la hoja de datos.
# Obsérvese que la puerta a la fuente de voltaje (VGS) es lo que impulsa a la FET.
# Esto produce excursiones en la corriente de drenaje a la fuente (IDS) que a su vez produce la oscilación del voltaje de salida al variar el voltaje de drenaje a la fuente (VDS).
#
#
# Asumimos que la resistencia de carga que requerimos es la que da nuestra potencia deseada para la máxima excursión posible del voltaje de salida, se calcula como $R_{LOAD} = \frac{(V_{DD} - V_{sat})^2}{2P_L}$, donde $V_{sat}$ es el valor mínimo que la tensión de la fuente de drenaje puede tener.
# Lo primero que hay que entender de la clase A es que vamos a sesgar el circuito de tal manera que la salida produzca la excursión completa de una onda sinusoidal lo mejor que pueda para la potencia dada.
#
# El siguiente circuito muestra la excursión de la salida para la máxima transferencia de potencia asumiendo que Vsat = 0. También usaremos esta figura para discutir los modos no lineales de alta eficiencia (clase AB,B y C) dentro de poco. Utilizamos una reactancia (resistencia de CC igual a cero) para conectar el desagüe a la fuente de alimentación, de modo que el sesgo de CC del desagüe sea igual al voltaje de la fuente (VCC).
# La transferencia óptima de energía ocurrirá cuando la resistencia de carga (que se ve aquí absorbiendo CDS en la red de adaptación de salida) tenga el valor correcto para hacer que la excursión de la corriente máxima sea igual a (VCC -Vsat)/Rload. No es posible que se produzcan oscilaciones de mayor amplitud que ésta, ya que bajo ninguna circunstancia un FET (o un BJT) con una alimentación entre tierra y un valor positivo puede conducir nunca una corriente negativa.
#
# ![5-cuatrocientos](fig/CLASSA_3.png)
#
# No olvides que estamos asumiendo que la red de emparejamiento ya está funcionando para producir la CARGA. Por eso estamos ocultando el hecho de que hay un CDS = 25 pF.
#
# Recuerden que no podemos hacer este diseño para 1 vatio para un solo amplificador porque en la clase A, la CARGA y el FET disipan la misma potencia y 1 vatio EXCEDE la potencia nominal del 2N7000.
#
# El voltaje de CC en el drenaje, VDS (bajo ninguna excitación) debe ser VCC. El valor mínimo de VDS es Vsat. La excursión máxima de pico en el desagüe es VCC + VCC - Vsat = 2VCC - Vsat y la oscilación de pico a pico es 2(VCC - Vsat). La corriente máxima en la carga es ILOAD = (VCC - Vsat)/CARGA y esto debe lograrse cuando la corriente de drenaje es cero Id = 0.
#
#
# El voltaje a través de la carga, Vt en cualquier momento es dado por,
# Vt = (VCC - Vsat)/CARGA sin(Wt)
#
# La corriente a través de la carga, en cualquier momento es dada por,
# It = Vt / RLOAD
#
# Debido a que el condensador de bloqueo tiene un voltaje de reposo VCC a través de él, el voltaje de drenaje es dado por,
# VDS = VCC + Vt
#
# La corriente en el estrangulador de la fuente de alimentación es una constante y viene dada por la corriente de carga cuando el FET se corta de la siguiente manera,
# ICHOKE = (VCC - Vsat) / RLOAD
#
# En el medio ciclo negativo de Vt la corriente de drenaje se obtiene del condensador de desacoplamiento que actúa como una especie de fuente de alimentación en esta circunstancia con una corriente igual del estrangulador y es dada por,
# max(IDS) = 2*(VCC - Vsat) / CARGA
#
# El valor mínimo del IDS se produce cuando el voltaje de drenaje alcanza su máximo y es,
# min(IDS) = 0
#
# Así que el IDS está dado por
# IDS = (VCC - Vsat)/RLOAD - Vt/RLOAD;
#
# Finalmente podemos escribir la línea de carga que es la relación entre IDS y VDS,
# IDS = (2VCC - Vsat - VDS)/CARGA;
#
# Algún código de MATLAB que hace esto por ti se adjunta al final de esta página.
#
# Si queremos 0,25 vatios de potencia para un suministro de 5 voltios, entonces usando la fórmula anterior y estimando Vsat = 0,2 voltios de las características IV anteriores, obtenemos la siguiente línea de carga,
#
#
# Observe que esto produce un valor conveniente accidental de CARGA = 46 Ohm. Como esto puede ser también 50 Ohms tenemos una tarea trivial de adaptación y podemos usar cualquier viejo filtro de paso bajo de Chebyshev para adaptarlo al preselector de antena (50 Ohms).
# Tenga en cuenta que todavía necesita una red de adaptación porque todavía tiene que absorber los 25 pF de capacitancia del CDS.
#
# Para hacer coincidir la entrada, sólo tiene que utilizar las técnicas de adaptación para hacer coincidir la señal de 20 dBm de una fuente de 50 Ohms con la impedancia de entrada. Note que la impedancia de entrada del FET es sólo CGS = 50 pF en paralelo con R1 = 68 Ohms en la figura simplificada de abajo. El valor real de R1 está determinado enteramente por el sesgo para poner la FET en el régimen de clase A de las características IV anteriores. Debido a que el CGS es tan grande (-j80 Ohms a 40 MHz), la parte real de la combinación paralela de CGS y R1 se divide de cualquier manera.

# %% [markdown]
# ## Amplificador de Potencia Lineal  Clase B tipo Push-Pull
#
# La amplificación en Clase B es mas eficiente que la A para amplificación de RF lineal, de ahí que se use la B con frecuencia en amplificadores de potencia lineales de mediana y alta potencia.
# La configuración mas común es el circuito acoplado a transformador en contrafase, aunque también se usan versiones complementarias similares a las usadas en amplificación en audio.
# También puede utilizarse una versión sintonizada de terminación única de banda estrecha, semejante a los amplificadores clase C.
#
# ![5-cuatrocientos](fig/Push_pull_1.png)
#
# Los principios de operación de un amplificadores de potencia clase B en RF son semejantes a los amplificadores de potencia clase B de AF. Los dos transistores se excitan desfasados en 180, para que cada uno esté activo durante medio ciclo y no opere el resto de éste.
# Cuando los transistores están en la región activa, son esencialmente fuentes de corriente.
# La alta eficiencia puede atribuirse a la corriente de colector nula en los transistores cuando sus tensiones de colector son los mas altos.
# Es importante observar que en la amplificación clase B ningún dispositivo por si mismo produce una replica amplificada de la entrada de amplificador.
# La señal es seccionada, amplificada eficientemente y después reensamblada.
#
# Supóngase que los dispositivos son perfectamente lineales y que cada uno es una fuente de corriente de media sinusoide con amplitud pico Icm.
# Durante un medio ciclo dado, solo un medio del devanado primario del transformador T1 lleva corriente.
# La transformación de la corriente en m vueltas del primario a n del secundario, produce una corriente de salida sinusoidal
#
# $$i_o(\theta) = \frac{n_p}{n_s} I_{cm} sen(\theta)$$
#
# que a su vez da lugar a una tensión de salida
#
# $$v_o(\theta) = \frac{n_p}{n_s} I_{cm} R_o sen(\theta)$$
#
#
# La transformación de esta tensión al devanado primario da la forma de onda de la
# tensión de colector
#
# $$v_{c1}(\theta) = V_{CC} + V_{cm} sen(\theta)$$
#
# donde la oscilación de la tensión de colector es
#
# $$V_{cm}(\theta) = \frac{n_p}{n_s} V_{o}= (\frac{n_p}{n_s})^2 I_{cm} R_o$$
#
#
# En la expresión anterior, R es la resistencia vista a través de la mitad del devanado
# primario, con la otra mitad abierta. Mantener una tensión de colector negativo requiere que $V_{cm} \le V_{CC}$, limitando así la potencia de salida a
#
# $$P_o  = \frac{V_{cm}^2}{2 R} \le \frac{V_{CC}^2}{2 R} = \frac{V_{CC}^2}{2(\frac{n_p}{n_s})^2 R_o}$$
#
#
# La corriente $i_{CT}(\theta)=I_{cm}|sen(\theta)|$ de derivación central es la suma de las dos corrientes de
# colector, y la corriente $I_{dc}$ de entrada es la componente continua de la corriente de derivación central, así
#
# $$I_{dc} = \frac{1}{2 \pi} \int^{2 \pi}_{0} i_{CT}(\theta) d\theta = \frac{2 I_{cm}}{\pi} = \frac{2 V_{cm}}{\pi R}$$
#
# La eficiencia en este caso es
#
# $$n = \frac{P_o}{P_i} = \frac{\pi}{4} \frac{V_{cm}}{V_{CC}} \le \frac{\pi}{4} \sim 0.785$$
#
# Como la tensión pico del colector es $V_{CC} + V_{cm} \le 2 V_{CC}$ y la potencia pico del colector es

# %%
import numpy as np
import matplotlib.pyplot as plt

import scipy                  # http://scipy.org/
from scipy.fftpack import fft, fftfreq
from time import time

# %matplotlib inline

params = {'legend.fontsize': 12,
          'figure.figsize': (6, 2),
         'axes.labelsize': 12,
         'axes.titlesize': 12,
         'xtick.labelsize':12,
         'ytick.labelsize':12}
plt.rcParams.update(params)

# Señal
VCC  =10

icq  = 1
icm  = .4
R    = 10

# defino el sampleo
n  = 100
# vector de tiempo 
th  = 2*np.pi*np.linspace(0, 1, num=n)


# modulante
ic   = icq - icm*(np.sin(th) )
io   = icm*(np.sin(th) )
vo   = R*io 
vce  = VCC+vo

ax = plt.plot(th, ic)
plt.ylabel('$i_c$ [A]')
plt.xlabel('$\theta$')
plt.ylim(-icq*0.1, icq*1.5)
plt.grid()
plt.show()

plt.plot(th, io)
plt.ylabel('$i_o$ [A]')
plt.xlabel('$\theta$')
#plt.ylim(0, icq*1.5)
plt.grid()
plt.show()

plt.plot(th, vo)
plt.ylabel('$i_o$ [V]')
plt.xlabel('$\theta$')
#plt.ylim(0, icq*1.5)
plt.grid()
plt.show()

plt.plot(th, vce)
plt.ylabel('$v_{ce}$ [V]')
plt.xlabel('${\theta}$')
plt.ylim(0, VCC*1.5)
plt.grid()
plt.show()

# %% [markdown]
# ## Serie de Fourier
#
#
# Si $f(t)$  es una función de variable real $t$, que es integrable en el intervalo $[-t_o-T/2,t_o+T/2]$  entonces se puede obtener el desarrollo en serie de Fourier de $f(t)$ en ese intervalo.
#
# Fuera del intervalo la serie es periódica, con período $T$.
#
# Si $f(t)$ es periódica en toda la recta real, la aproximación por series de Fourier también será válida en todos los valores de $t$.
#
# ### Serie de Fourier trigonometrica
#
# Luego la serie de Fourier asociada a $f(t)$ es:
#
# $f(t) \sim \frac{a_0}{2} + \sum_{n=1}^\infty [ a_n cos(\frac{2n\pi}{T} t) + b_n sin(\frac{2n\pi}{T} t)]$
#
# Donde $a_0$, $a_n$ y $b_n$ son los coeficientes de Fourier que toman los valores:
#
# $a_0 = \frac{2}{T} \int_{t_o}^{t_o+T}  f(t) dt$
#
# $a_n = \frac{2}{T} \int_{t_o}^{t_o+T}  f(t) cos(\frac{2 n \pi}{T} t) dt$
#
# $b_n = \frac{2}{T} \int_{t_o}^{t_o+T}  f(t) sin(\frac{2 n \pi}{T} t) dt$
#
#
# ### Serie de Fourier exponencial
#
# Por la identidad de Euler, las fórmulas de arriba pueden expresarse también en su forma compleja:
#
# $f(t) \sim \sum_{n=-\infty}^{\infty} c_{n} e^{j 2 \pi \frac{n}{t}}$
#
# Los coeficientes ahora serían:
#
# $c_n = \frac{1}{T}\int_{t_o}^{t_o+T} f(t)\,e^{-2\pi i \frac{n}{T} t} dt$
#
# Otra forma de definir la serie de Fourier es:
#
# $f(t) = \frac{a_0}{2} + \sum_{n=1}^\infty a_n cos(2 \pi n) + b_n sin(2 \pi n)$
#
# donde $\omega_n = n\omega$ y $\omega = 2 \pi f_o = \frac{2 \pi}{T}$
#
# siendo:
#
# $a_0 = \frac{2}{T} \int_{t_o}^{t_o+T} f(t) dt$
#
# $a_n = \frac{2}{T} \int_{t_o}^{t_o+T} f(t) cos(\omega_n t) dt$
#
# $b_n = \frac{2}{T} \int_{t_o}^{t_o+T} f(t) sin(\omega_n t) dt$
#
# Esta forma de la serie de Fourier se le conoce como la serie trigonométrica de Fourier.
#
# ### Euler's formula:
# $e^{ i \theta} = cos(\theta) + i \cdot sin(\theta)$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Estas funciones calculas las componentes de la serie de Fourier para una senal dada
# A cada función se pasa como argumento la señal x y el numero de armonico a calcular.
# El muestreo se define por la cantidad de muestras dentro del periodo de la señal x.

# Serie trigonometrica
def DFTT(x, k):
    N = len(x)
    a = 2/N*sum([s*np.cos(2*np.pi*i/N*k) for i,s in enumerate(x)])
    b = 2/N*sum([s*np.sin(2*np.pi*i/N*k) for i,s in enumerate(x)])
    if k == 0 : a = a /2.
    return a,b

# defino el sampleo
n   = 100
# vector de tiempo 
th  = 2*np.pi*np.linspace(0, 1, num=n)

# frecuancia de la señal
fm   = 10 #Hz
# Amplitud
Ac   = 1 

# senal pulso coseno de frecuencia 10 Hz, 

# muestrea a 100 Sps (muestras por segundo). 
# defino el muestreo
fs =  100*fm #Sps

# Muestreo: tiempo máximo del analisis (periodo de la ventana)
T = 1/fm 

# Defino el vector de tiempo del muestreo
time  = np.arange(-T/2, T/2, 1/fs)

# Pulso clase B (coseno)
Sm   = Ac*np.cos(2*np.pi*fm*time)  
# Señal Pulso de coseno
Sp   = np.array([s if s >=  0 else 0  for s in Sm]) 

plt.plot(time, Sp)
plt.ylabel('$i_{o}$ [A]')
plt.xlabel('${\theta}$')
#plt.ylim(0, Ic*1.5)
plt.grid()
plt.show()

# Serie de Fourier Trigonometrica
# la separacion de las deltas = 1/T  
freq = np.arange(0,fs/2,1/T)

a = [DFTT(Sp,n)[0] for n in range(len(freq))]
b = [DFTT(Sp,n)[1] for n in range(len(freq))]

ab = [(a[i]+1j*b[i]) for i in range(len(a))] # debido al defasaje se emplea la variacion de j
for i in range(7):
    print('a{:1} ={:.2f}'.format(i, np.abs(ab)[i]) )


plt.stem( freq, np.abs(ab))
plt.xlim([-2  , 100])
plt.ylim([-0.1, 4.7])
plt.ylabel('abs')
plt.xlabel('freq/Hz')
plt.grid()
plt.show()
# Out:
# a0 =0.32
# a1 =0.50
# a2 =0.21
# a3 =0.00
# a4 =0.04
# a5 =0.00
# a6 =0.02
# /home/aalmela/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:62: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %% [markdown]
# ## Metodo de los trapecios
#
# El metodo de los trapecios permite calcular las componentes de Fourier de forma aproximada empleando un muestreo discreto.
#
# Este metodo emplea trapecios para estimar el area de calculada por la integral en las componentes de Fourier.
#
#
# $f(t) = {a_0} + \sum_{n=1}^\infty\left(a_n\cos\left( \frac{2\pi}{T}\cdot  n \cdot t \right) + b_n\sin \left( \frac{2\pi}{T} \cdot  n \cdot t \right) \right)$
#
#
# siendo:
#
# $ a_0 = \frac{1}{T} \sum_{i=\frac{-N}{2}}^{\frac{N}{2}-1} f(T_s \cdot i) \cdot T_s $
#
# $ a_n = \frac{2}{T} \sum_{i=\frac{-N}{2}}^{\frac{N}{2}-1}  f(T_s \cdot i) \cdot \cos{(\frac{2\cdot \pi }{T} \cdot n \cdot T_s \cdot i )} \cdot T_s $
#
# $ b_n = \frac{2}{T} \sum_{i=\frac{-N}{2}}^{\frac{N}{2}-1}  f(T_s \cdot i) \cdot \sin{(\frac{2\cdot \pi }{T} \cdot n \cdot T_s \cdot i )} \cdot T_s $
#
# donde:
# $ T   $ es el periodo de la señal, $ T_s $ es el periodo del muestreo y $ N = \frac{T}{T_s} $
#
# Si $N = 24$  resulta entonces (valido para una función par):
#
# $ a_0 = \frac{1}{12} \sum_{i=0}^{\frac{N}{2}-1} f(T_s \cdot i) =  \frac{1}{12} ( \frac{A+B}{2} + \frac{B+C}{2} + \frac{C+D}{2}+ \frac{D+E}{2}+ \frac{E+F}{2}+ \frac{F+G}{2}+ \frac{G+H}{2} + \frac{H+I}{2}+ \frac{I+J}{2}+ \frac{J+K}{2} )   $
#
# $ a_0 = \frac{1}{12} ( \frac{A}{2} + B + C + D +E+ F  + G + H + I + J + \frac{K}{2})   $
#
#
# $ a_n = \frac{1}{6} \sum_{i=0}^{\frac{N}{2}-1}  f(T_s \cdot i) \cdot \cos{(\frac{2\cdot \pi }{24} \cdot i \cdot n )} $
#
# $ a_n =  \frac{1}{6} ( \frac{A}{2}  + B \cos{\frac{\pi }{12}}+ C \cos{\frac{2\cdot \pi }{12}}+ D\cos{\frac{3\cdot \pi }{12}}+ E\cos{\frac{4\cdot \pi }{12}} + F \cos{\frac{ \cdot \pi  }{12}}+ G \cos{ \frac{ \cdot \pi }{12}}+ H \cos{\frac{7 \cdot \pi }{12}}+ I \cos{\frac{8\cdot \pi }{12}}+ J \cos{\frac{9\cdot \pi }{12}}+ \frac{K}{2}\cos{\frac{10\cdot \pi }{12}} )  $
#
#
# $ b_n = 0 $

# %%
# senal pulso coseno de frecuencia 100 Hz, muestrea a 100e3 Sps (muestras por segundo). 
# En este caso N es 24 
# defino el sampleo
fs = fm*24 #Sps 

# Defino el vector de tiempo del muestreo
time  = np.arange(-T/2, T/2, 1/fs)

# Señal coseno
Sm   = [Ac*np.cos(2*np.pi*fm*t) for t in time] 
# Señal Pulso de coseno
Sm   = [s if s > 0 else 0  for s in Sm] 

# Defino el vector 
myPoint  = [ 'A','B','C','D','E','F','G','H','I','J','K']

plt.plot(time, Sm)
plt.plot(time, Sm, 'ro')
for i, mp in enumerate(myPoint):
    plt.text(time[i+12], Sm[i+12] +0.02, mp, fontsize=12)
    plt.fill_between(time[i+12:i+14], 0, (Sm[i+12] + Sm[i+13] )/2 )
plt.ylim([-0.2,Ac*1.2])
plt.show()

# %% [markdown]
# ## Amplificadores no lineales Clase AB, B y C
#
# https://sci-hub.tw/10.1109/JSSC.1967.1049799
#
#
# El amplificador de potencia de clase C es un tipo de amplificador en el que el elemento activo conduce durante menos de medio ciclo de la señal de entrada. Menos de un medio ciclo significa que el ángulo de conducción es inferior a $\theta_c \le 180$ y su valor típico es de $\theta_c = 80$ a $\theta_c = 120$.
# El ángulo de conducción reducido mejora la eficiencia en gran medida pero causa mucha distorsión.
# La eficiencia máxima teórica de un amplificador de clase C es de alrededor del $90\%$.
#
# La aplicación más común del amplificador de Clase C son los circuitos de RF (radiofrecuencia) como el oscilador de RF, el amplificador de RF, etc., donde hay circuitos sintonizados adicionales para recuperar la señal de entrada original de la salida pulsada del amplificador de Clase C y, por lo tanto, la distorsión causada por el amplificador tiene poco efecto en la salida final.
#
# http://localhost:8888/notebooks/scm/git/utn/eaiii/2020/1_Introduccion/2_Modulaciones_y_Serie_de_Fourier/Intermodulacion.ipynb

# %%
import numpy as np
import matplotlib.pyplot as plt

# Estas funciones calculas las componentes de la serie de Fourier para una senal dada
# A cada función se pasa como argumento la señal x y el numero de armonico a calcular.
# El muestreo se define por la cantidad de muestras dentro del periodo de la señal x.

# Serie trigonometrica
def DFTT(x, k):
    N = len(x)
    a = 2/N*sum([s*np.cos(2*np.pi*i/N*k) for i,s in enumerate(x)])
    b = 2/N*sum([s*np.sin(2*np.pi*i/N*k) for i,s in enumerate(x)])
    if k == 0 : a = a /2.
    return a,b

# defino el sampleo
n   = 100
# vector de tiempo 
th  = 2*np.pi*np.linspace(0, 1, num=n)

# frecuancia de la señal
fm   = 1/(2*np.pi) #rad
# Amplitud
Ac   = 1 

# Muestreo: tiempo máximo del analisis (periodo de la ventana)
T = 1/fm 

# Pulso 
Sm   = Ac*np.sin(th)  

thc  = 1*np.pi
# Señal Pulso de coseno
Sp   = np.array([Sm[i] if t <= thc  else 0  for i,t in enumerate(th)]) 

plt.plot(th, Sp)
plt.ylabel('$i_{o}$ [A]')
plt.xlabel('${\theta}$')
#plt.ylim(0, Ic*1.5)
plt.grid()
plt.show()

# Serie de Fourier Trigonometrica
# la separacion de las deltas = 1/T  
freq = np.arange(0,n*fm/2,1/T)

a = [DFTT(Sp,m)[0] for m in range(len(freq))]
b = [DFTT(Sp,m)[1] for m in range(len(freq))]

ab = [(a[i]+1j*b[i]) for i in range(len(a))] # debido al defasaje se emplea la variacion de j
for i in range(7):
    print('a{:1} ={:.2f}'.format(i, np.abs(ab)[i]) )


plt.stem( freq, np.abs(ab))
plt.xlim([-0.5*fm,fm*10])
plt.ylabel('abs')
plt.xlabel('freq/Hz')
plt.grid()
plt.show()

VDC = 10
PDC = VDC*abs(ab[0])

PL  = VDC*abs(ab[1])/2

rendimiento = PL/PDC

print(abs(PDC),abs(PL),rendimiento)
# Out:
# a0 =0.32
# a1 =0.50
# a2 =0.22
# a3 =0.00
# a4 =0.04
# a5 =0.00
# a6 =0.02
# /home/aalmela/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:55: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# 3.1510034249551144 2.487330868028244 0.789377392715362

# %% [markdown]
# ## Consideraciones Practicas
#
# La operación de un amplificador real no es tan buena como la pronosticada para el modelo ideal, pues los dispositivos reales tienen tensiones o resistencias de saturación, y cargas reales que incluyen reactancia.
# En altas frecuencias, los efectos de almacenamiento de carga pueden causar distorsión, de la forma de onda de corriente de colector, reduciendo en mas la eficiencia.
# En general, estos efectos se pueden despreciar cuando $f \le \frac{f_T}{10}$, aunque adquieren mucha importancia cuando $f < \frac{f_T}{2}$.
#
# ### Tensión de Saturación
#
# Los transistores bipolares se caracterizan por una tensión colector-emisor bastante constante durante la saturación.
# Un BJT en lo circuitos amplificadores de potencia, entrará a la saturación siempre que el amplificador de potencia se excite lo suficiente, de tal suerte que el tensión de colector instantáneo mínimo sea igual al tensión $V_{CE(SAT)}$ de saturación.
#
#
# Para evitarla, la señal excitación se debe conservar lo suficientemente pequeña para mantener la oscilación de tensión de colector debajo de $V_{eff} = V_{CC} - V_{CE(SAT)}$.
#
#
# La tensión de salida máxima, la potencia de salida y las corrientes de salida y entrada se calculan usando el tensión de alimentación efectivo $V_{eff}$ en lugar del $V_{CC}$.
#
# Sin embargo, la potencia de entrada se calcula usando la $V_{CC}$.
# Esto reduce la eficiencia máxima en un factor de $\frac{V_{eff}}{V_{CC}}$, por ejemplo, la eficiencia máxima de un amplificador de potencia en clase A y B se reduce a  $\pi$ ($\frac{V_{eff}}{V_{CC}}$) y $\frac{\pi}{4}$ ($\frac{V_{eff}}{V_{CC}}$), respectivamente.
#
#
# En bajas frecuencias, ($f < \frac{f_T}{10}$), $V_{sat}$ es simplemente la $V_{CE}(sat)$ especificado para el
# dispositivo (por lo común $V_{CE}(sat)=0.3V$ para transistores de silicio en corrientes débiles).
# Si se usa una configuración Darlington, $V_{sat} \sim V_{CE}(sat) + V_{p}$ donde $V_{p}$ es la caída de tensión entre base y emisor con polarización directa (por lo general, $V_{sat} \sim 0.7V$ para transistores de silicio).
# En frecuencias mas elevadas ($f > \frac{f_T}{10}$), $V_{sat}$ se hace mayor que $V_{CE}(sat)$ para operación en régimen permanente.
# El incremento en $V_{sat}$ está relacionado con el tiempo que se requiere para que el transistor completo llegue a saturarse. Esta tensión de RF de saturación puede ser tan alta como 1V o 2V y algunas veces se especifica en los manuales de operación.
# Resistencia de Saturación
#
#
# La resistencia de saturación Ron (o resistencia de encendido) de los FET’s, como las tensiones de saturación de los BJTs, limita la salida máxima pero no afecta la operación en la región activa.
# La saturación se presenta cuando la tensión de drenaje instantánea mínima es igual al producto de la corriente de drenaje por la resistencia de saturación; es decir, para la clase B, $V_{DD} - I_{dm}R = I_{dm}R_{on}$.
# Consecuentemente, para evitar saturación, $V_{dm}$ debe ser menor que la tensión de alimentación efectiva: $V_{eff} =R + Ron V_{DD}$
#
# Para operación en clase A o para un amplificador de potencia clase B sintonizado con terminación única, se duplican los efectos de $R_{on}$; es decir, $V_{eff} = \frac{V_{DD}R}{R+2R_{on}}$.
#
# En cualquier caso, la tensión, la potencia de salida máximos y la corriente de entrada se calculan usando el $V_{eff}$ y la potencia de entrada se calcula entonces usando $V_{DD}$, como para los efectos de tensión de saturación.
#
#
# ### Distorsión    de  Intermodulación    y  Polarización
#
# La distorsión de intermodulación (IMD) consiste en aquellos productos de distorsión
# que ocurren cerca de la frecuencia portadora y proviene de la incapacidad de un amplificador de potencia en RF para reproducir exactamente la envolvente y la fase de la señal de entrada. La reproducción exacta de la portadora sinusoidal es innecesaria, pues las armónicas se remueven por el circuito de salida sintonizada o por el filtro. Dos causas importantes de IMD son los efectos de cruce por cero y la reducción de ganancia con corriente elevada. Otras dos de son la saturación del dispositivo y la variación de la capacitancia del colector con el tensión de colector.
#
# La saturación origina tanto un "aplanamiento de cima" como modulación de fase indeseada (debida a efectos de tiempo de almacenamiento) y se evita no sobreexcitando al amplificador (es decir, no excediendo la salida máxima para la clase de operación que se pretende). La capacidad variable con la tensión es inherente a las uniones de semiconductores, aunque su efecto es por lo común pequeño en la mayoría de las aplicaciones de amplificadores de potencia.
#
# La distorsión de intermodulación se mide generalmente con una señal de prueba
# compuesta de dos sinusoides de amplitudes iguales pero separadas en frecuencia por una frecuencia de 1 a 2 KHz. Los productos resultantes se denominan de tercer orden, de quinto orden, y así sucesivamente, de la misma manera que los productos de mezcladores. La medida que mas comúnmente se emplea para la IMD representa la razón que existe entre el producto mas grande de intermodulación con la amplitud de uno de los dos tonos; -30 dB es usualmente la razón IMD menos aceptable, pero aun tolerable, en un transmisor. Esta razón se mide fácilmente con un analizador de espectro, pero es demasiado pequeña para medirse con exactitud en un osciloscopio (o aun detectarse). Es interesante observar que si los productos de intermodulación en las bandas laterales superior e inferior son idénticas, son el resultado de una distorsión ya sea de la envolvente pura o de la fase pura; en cambio los productos de intermodulacion desiguales del mismo orden indican distorsión simultánea de fase y envolvente.
#
# ### Distorsión cruzada y polarización
#
# Los dispositivos reales (BJTs, FETs o tubos de vacío) operados en clase B, no
# cambian bruscamente de un modo de corte a uno activo (fuente de corriente lineal). El cambio real es gradual y no lineal. En consecuencia, el efecto denominado "distorsión cruzada", altera la forma de onda cuando un dispositivo entra en corte y el otro se torna activo. Estos efectos son más pronunciados con señales de amplitud relativamente pequeñas (respecto a la salida máxima del amplificador de potencia).
#
# La distorsión cruzada se reduce al mínimo polarizando las bases o compuertas del dispositivo para producir una pequeña corriente estable en el colector o drenaje. Una corriente estable demasiado pequeña, no da lugar a salida cuando la entrada no alcanza la amplitud mínima requerida. Demasiada polarización se traduce en ganancia excesiva para señales de pequeña amplitud.
#
# La cantidad de corriente estable para tener distorsión mínima se determina experimentalmente en forma más directa, pues la predicción teórica es sumamente complicada. Por lo común, la razón IMD mínima ocurre con una corriente estable que tiene entre $1 y 10 \%$ de la corriente pico del colector o de drenaje; el valor exacto rara vez es crítico.
# En virtud de esta corriente estable, cada dispositivo lleva corriente durante un poco más de un medio ciclo de radio frecuencia. Esto explica el uso del término clase AB para los amplificadores de potencia con tubos de vacío y para algunos de los primeros amplificadores de potencia de estado sólido; sin embargo, muchos autores usan simplemente clase B, sobreentendiéndose que se usará una corriente estable.
#
# ## Fuente de Polarización
#
# La polarización adecuada en los amplificadores de potencia con FET, se obtiene
# fácilmente de una tensión de alimentación regulada, mediante un divisor de tensión resistivo ajustable y una red de “puenteo” adecuada. Sin embargo, la polarización de tensión simple no se puede usar con los amplificadores de potencia con BJT. El efecto de incrementar la temperatura de una unión PN equivale más o menos en desplazar las características del dispositivo en aproximadamente 2 mV/ºC; es decir, un aumento de 1 ºC en la temperatura produce aproximadamente el mismo incremento en la corriente que produciría un incremento de 2 mV en el tensión de juntura. Supóngase que se aplica una tensión de polarización VBE de un BJT y que se ajusta la tensión rápidamente para producir la corriente de colector estable deseada. Esta corriente hace que se disipe potencia en el transistor, elevando le temperatura de la unión. Esto a su vez incrementa la corriente de colector, lo cual da lugar a un aumento en la disipación. Como hay poca resistencia de corriente contínua en el circuito de colector; casi no hay límite para la corriente de colector que se puede obtener. Este proceso se denomina desbordamiento térmico y conduce a la destrucción del dispositivo.
# Es obvio que para mantener una corriente estable de colector esencialmente constante se requiere una fuente de tensión de polarización que decrezca al producirse una temperatura de unión de aproximadamente 2mV/ºC. Una fuente así se puede obtener montando un diodo de construcción similar a la del transistor de potencia de RF sobre el disipador de calor y polarizando con una corriente constante.
#
#
# Las fuentes de polarización para operación clase A son semejantes a las de la clase
# B. Aunque se requiere más corrientes de base (IBB +IC/β) se puede permitir una variación fraccionaria de IC ligeramente mayor con temperatura, pues su efecto sobre la IMD es pequeño.
#
# ### Excitación BJTs.
#
# La relación entre la corriente de colector y el tensión base-emisor en BJT es exponencial y por consiguiente es inherentemente no lineal en operación con señal fuerte. Por esta razón, los amplificadores de potencia usan a menudo excitación con corriente en vez de con tensión. Las corrientes de colector y, de base están relacionadas casi linealmente pues el tensión base-emisor es función logarítmica de la corriente inyectada a la base. Idealmente, las funciones logarítmicas y exponenciales se cancelan mutuamente, aunque en la práctica no hay una linealidad perfecta.
#
# Para comprender cómo se excita una amplificadores de potencia en clase B que  utiliza BJTs, supóngase que se inyecta una corriente sinusoidal al devanado primario del transformador T1.
# Durante el medio ciclo positivo de esta corriente, la corriente en el devanado secundario tiende a fluir de la base de Q2 hacia la de Q1. Como esta dirección de flujo de corriente está en dirección inversa de la base de Q2, y directa de la de Q1, la corriente fluye sólo desde la derivación central hacia la base de Q1. Esta corriente hace que la tensión vB1(θ) se eleva por encima de la de polarización VBB. El transformador refleja esto como un descenso en el tensión vB2(θ) de la base del Q2, como se muestra en la figura 9.10. Durante el medio ciclo negativo de la corriente de excitación, la base del Q2 se polariza directamente en forma similar y, la del Q1 queda polarizada inversamente en manera semejante. Si no se toman en cuenta las reactancias parásitas y las capacitancias de transistor, sólo se tiene una base en el circuito en un tiempo dado.
#
#
# Si se supone ganancia constante β de corriente, cada base requiere corriente de  excitación semisinusoidal con amplitud pico Icm/β. La corriente sinusoidal de excitación tendrá así una amplitud pico de (Icm/β)(n/m). En cualquier instante, el tensión de excitación vD(θ), está formada por la transformación mediante T1 de la forma de onda de tensión existente en la base polarizada directamente. Aunque la forma de onda vD(θ) es no sinusoidal, conviene suponerla sinusoidal. Su amplitud pico es entonces (m/n)(Icm/β)RB, donde RB es la resistencia de base equivalente bajo señal fuerte. Esta resistencia puede definirse como (m/n)2 veces la razón entre la componente de frecuencia fundamental de la tensión de excitación y la amplitud de la corriente de excitación. Los valores de RB (o de la impedancia ZB) se dan por lo general en los manuales de transistor; por lo común, van de uno a varios Ohms. Este valor se puede usar para determinar la potencia de excitación requerida:
#
#
# y la resistencia RD de punto de. excitación, que es (m/n)2RB. La ganancia en potencia. se puede calcular como la razón entre las potencias de salida y de excitación.
# FETs. En operación clase A, la relación ideal de ley cuadrática entre el tensión
# compuerta-fuente y la corriente de drenaje no introduce distorsión en la señal de frecuencia fundamental. No obstante, en clase B, la característica ideal de ley cuadrática se traduce en una relación de ley cuadrática (es decir, no lineal), entre las amplitudes de las componentes de la frecuencia fundamental de las señales de entrada y salida. Por fortuna, los FETs de potencia VMOS poseen características de ley cuadrática en niveles bajos y lineales en niveles medios y altos. Los efectos de la región de ley cuadrática conducen a distorsión cruzada y pueden reducirse al mínimo mediante una elección adecuada del tensión de polarización.
# La excitación de un amplificadores de potencia con FET debe producir tensiones de
# compuerta que correspondan a las corrientes de drenaje deseadas. La impedancia de entrada de un MOSFET es esencialmente una reactancia capacitiva grande, con una componente resistiva pequeña debida al acoplamiento compuerta-drenaje-carga. En consecuencia, la impedancia de entrada un amplificador de potencia con FET es por lo general más elevada (y la potencia de excitación es generalmente más baja) que en un amplificadores de potencia que utilice BJTs comparables.

# %% [markdown]
# ## REDES DE ADAPTACIÓN DE IMPEDANCIA APLICADAS A TRANSISTORES DE POTENCIA DE RF
#
# (AN-721)
#
# Aquí se revisarán algunos métodos gráficos y numéricos de comparación de impedancias.
# Los ejemplos dados se referirán a los amplificadores de potencia de alta frecuencia.
# Aunque las redes de adaptación suelen adoptar la forma de filtros y, por lo tanto, también son útiles para proporcionar una discriminación de frecuencia, este aspecto sólo se considerará como un corolario del circuito de adaptación.
#
# Adaptar impedancias es necesario para lograr la mayor transferencia de energía de una etapa a otra.
# En los transistores de potencia de RF la impedancia de entrada es de bajo valor, disminuyendo a medida que aumenta la potencia, o a medida que el tamaño del chip se hace más grande.
# Esta impedancia debe ser igualada ya sea a un generador - de una impedancia interna generalmente de 50 ohmios - o a una etapa precedente.
# Las relaciones de transformación de la impedancia de 10 o incluso 20 no son raras. La adaptación entre etapas debe hacerse entre dos impedancias complejas, lo que hace que el diseño sea aún más difícil, especialmente si la adaptación debe hacerse en una banda de frecuencia amplia.
#
# ###  PARÁMETROS DEL DISPOSITIVO
#
# #### IMPEDANCIA DE ENTRADA
# La forma general de la impedancia de entrada de los transistores de potencia de RF es como se muestra en la Figura 1.
# Se trata de un parámetro de señal grande, expresado aquí por la combinación en paralelo de una resistencia Rp y una reactancia Xp (Ref. (1)).
# El circuito equivalente que se muestra en la Figura 2 explica el comportamiento ilustrado en la Figura 1.
# Con la línea de banda actualmente usada o el empaque de brida, la mayoría de los dispositivos de potencia para la banda baja de VHF tendrán sus valores de Rp y Xp por debajo del punto resonante en serie fs.
#
#
# La impedancia de entrada será esencialmente capacitiva
#
# ![5-cuatrocientos](fig/AN721_1.png)
#
#
# ![5-cuatrocientos](fig/AN721_2.png)
#
# La mayoría de los transistores de banda alta de VHF tendrán la frecuencia resonante en serie dentro de su rango de operación, es decir, serán puramente resistivos en una sola frecuencia fs, mientras que la frecuencia resonante paralela fp estará fuera.
#
# Los parámetros de los transistores de uno o dos gigahercios estarán más allá de fs y se acercarán a fp.  Muestran un alto valor de Rp y Xp con carácter inductivo.
#
# Un parámetro que se utiliza muy a menudo para juzgar las capacidades de banda ancha de un dispositivo es la entrada Q o Qin definida simplemente como la relación Rp/Xp.
# Prácticamente el QlN oscila alrededor de 1 o menos para los dispositivos de VHF y alrededor de 5 o más para los transistores de microondas.
# QIN es un parámetro importante a considerar para la adaptación de la banda ancha.
# Las redes de emparejamiento normalmente son filtros de paso bajo o pseudo-paso bajo.
# Si el QlN es alto, puede ser necesario utilizar redes de emparejamiento de tipo filtro pasabanda y permitir pérdidas de inserción.
# Pero el emparejamiento de banda ancha todavía es posible.
# Esto se discutirá más adelante.
#
#
# ####  IMPEDANCIA DE SALIDA
#
# La impedancia de salida de los transistores de potencia de RF, tal como se indica en las hojas de datos de todos los fabricantes, generalmente consiste sólo en un COUT de capacitancia.
# Se supone que la resistencia interna del transistor es mucho mayor que la carga y normalmente se descuida. En el caso de una resistencia interna relativamente baja, la eficiencia del dispositivo disminuiría por el factor
#
# $$1+ \frac{R_L}{R_T}$$
#
# donde RL es la resistencia de carga, vista en los terminales del colector-emisor, y RT la resistencia del transistor interno igual a
#
# $$\frac{1}{\omega_T (C_{CT}+C_{DC})}$$
#
#
# definido como un pequeño parámetro de señal, donde: wT= frecuencia angular de tránsito CTC + CDC = capacitancias de transición y difusión en la unión del colector
#
# La capacitancia de salida COUT, que es un parámetro de señal grande, está relacionada con el parámetro de señal pequeña CCB, la capacitancia de transición de la base del colector.
# Dado que la capacitancia de unión varía con el voltaje aplicado, COUT difiere de CCB en que tiene que ser promediada sobre la oscilación total del voltaje.  Para una unión abrupta y asumiendo ciertas simplificaciones, COUT = 2 CCB. La figura 3 muestra la variación del COUT con la frecuencia. COUT disminuye en parte debido a la presencia de la inductancia del colector de plomo, pero principalmente por el hecho de que el diodo emisor de base ya no se apaga cuando la frecuencia de funcionamiento se acerca a la frecuencia de tránsito fT.
#
# #### Carga de salida
#
# A falta de una indicación más precisa, la carga de salida RL se toma igual a
#
# $$R_L = \frac{(V_{CC}-V_{CE(SAT)})^2}{2 P_o}$$
#
# con VCE(sat) igual a 2 o 3 voltios, aumentando con la frecuencia. La ecuación anterior sólo expresa una relación bien conocida, pero también muestra que la carga, en una primera aproximación, no está relacionada con el dispositivo, excepto para el VCE(sat).  El valor de la carga viene dictado principalmente por la potencia de salida requerida y el pico de tensión; no se corresponde con la impedancia de salida del dispositivo. A frecuencias más altas esta aproximación se hace menos exacta y para los dispositivos de microondas la carga que debe presentarse al dispositivo se indica en la hoja de datos. Este parámetro se medirá en el futuro en todos los dispositivos de potencia de RF de Motorola. En sentido estricto, la adaptación de la impedancia se realiza sólo en la entrada.  La coincidencia entre etapas y la coincidencia de carga son más transformaciones de la impedancia de entrada del dispositivo y de la carga en un valor RL (a veces con un componente reactivo adicional) que depende esencialmente de la potencia demandada y del voltaje de suministro.
#
# #### Redes de adaptación
#
# En las siguientes redes de coincidencia se describirán por orden de complejidad.   Estas son redes de reactancia de tipo escalera
#
# Los diferentes valores de reactancia serán calculados y determinados gráficamente. Aumentar el número de reactancias amplía el ancho de banda.  Sin embargo, las redes que consisten en más de cuatro reactancias son raras. Por encima de cuatro reactancias, la mejora es pequeña.

# %% [markdown]
# ## Apartado 1
#
# ### Medicion de los parametros
#
# Aunque los ingenieros de diseño encontrarán la caracterización de la impedancia de la gran señal en las hojas de datos para los transistores de potencia de RF, puede ayudar a saber cómo se obtienen estos datos.
#
# El transistor se coloca en un circuito de prueba diseñado para proporcionar una amplia capacidad de sintonización. El diseño del primer amplificador de prueba para un nuevo tipo de transistor se basa en estimaciones de la impedancia de entrada y de salida.
#
# Dado que las impedancias de entrada y salida son necesarias para diseñar un amplificador que luego se utiliza para medir las impedancias del dispositivo, tenemos un problema del tipo "el huevo o la gallina".
# Las redes de amplio rango de sintonía ayudan a compensar los errores en las estimaciones de impedancia y también permiten utilizar el mismo amplificador de caracterización en múltiples niveles de potencia de salida.
#
# El amplificador se sintoniza para una condicion luego de iteraciones de impedancia tanto en la entrada como en la salida.
# Se deben tomar varias precauciones para asegurar que esto se logre.
# La sintonización para la salida de máxima potencia es válida sólo si las impedancias de la fuente y de la carga son de $50 \Omega$.
#
# Por lo general, en el laboratorio se dispone de una buena carga de $50 \Omega$.
# Dicha carga debe utilizarse, ya que la sintonización para la máxima potencia de salida para una potencia de entrada determinada es el mejor método a utilizar en la red de salida del amplificador.
#
# La red de entrada plantea algunos problemas adicionales.
# En primer lugar, muchas fuentes de energía de RF de laboratorio no son generadores de $50 \Omega$.
# Una impedancia del generador que no sea de $50 \Omega$ puede introducir errores en la medición de la ganancia así como en las impedancias de entrada.
# Además, una fuente con un alto nivel de exploración armónica causa dificultades en las redes de entrada de baja Q.
# Una buena solución a este problema es utilizar un acoplador direccional doble o un medidor de potencia direccional en la línea coaxial entre el generador y el amplificador de prueba.
#
# A continuación, el amplificador se sintoniza para que la potencia reflejada sea cero, lo que indica que la red de entrada está realmente adaptada a la impedancia de entrada del transistor a $50 \Omega$.
# En la práctica, la potencia reflejada no suele ser nula hasta el cero, por lo que hay que asegurarse de que el nulo sea al menos tan profundo como el que se obtiene con una buena pasiva terminación de 50 ohmios.
#
# En algunos casos, el amplificador reflejará suficiente potencia armónica, para evitar que se obtenga nula potencia reflejada, una buena solución a este problema es colocar un filtro pasabanda de frecuencia fundamental en el puerto de potencia reflejada del acoplador direccional doble.
#
#
# ![5-cuatrocientos](fig/AN282A_6.png)
#
# En la figura se muestra un amplificador de prueba típico para las mediciones de HF y VHF.  Para la caracterización de los dispositivos de UHF, lo más común es el uso de amplificadores que emplean redes de adaptación de microstrips. Después de que el amplificador de prueba se haya sintonizado correctamente, la potencia de CC, la fuente de la señal, la carga del circuito y el transistor de prueba se desconectan del circuito.
#
# ![5-cuatrocientos](fig/AN282A_7.png)
#
#
# Entonces la fuente de la señal y las conexiones del circuito de carga de salida se terminan cada una con 50 ohmios.   Después de realizar estas sustituciones, se miden las impedancias complejas en las conexiones del circuito de base y del colector del transistor de prueba (puntos A y B respectivamente en la figura 7).
# Los datos deseados, las impedancias de entrada y salida del transistor, serán los conjugados de la conexión del circuito de base y la conexión del circuito colector, impedancias respectivamente.operando los amplificadores de prueba a varias frecuencias diferentes con al menos dos salidas de potencia, se pueden obtener suficientes datos para caracterizar un transistor para la mayoría de sus aplicaciones de potencia
#
#
# https://cdn.macom.com/datasheets/MRF448A.pdf
#
# https://cdn.macom.com/datasheets/MRF173.pdf
