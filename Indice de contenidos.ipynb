# %% [markdown]
# # Contenido
#
# ## Unidad temática I: Sistemas de radiocomunicación
#
# ### [Didactica 1:](./1_Introduccion/Didactica_1.ipynb)
#
#
# Diagrama en bloques de un Transmisor y Receptor.
#
# Receptores Homodinodo y Heterodino.
#
# Dispositivos pasivos y activos en RF.
#
# Definiciones potencia Tx (dB, dBm), sensibilidad Rx.
#
#
# ## Unidad temática II: Circuitos de adaptación
#
# ### [Didactica 2:](./2_Circuitos_de_adaptacion/1_Didacticas/Didactica_2.ipynb)
#
# Teoría básica de la adaptación.
#
# Modelo de componentes pasivos en RF.
#
# Transformación serie paralelo e inversa.
#
# Utilización LTSpice.
#
# ### [Didactica 3:](./2_Circuitos_de_adaptacion/1_Didacticas/Didactica_3.ipynb)
#
# Máxima transferencia de energía a Q constante.
#
# Circuitos "L" invertida.
#
# Bobina en derivación e inductancia mutua.
#
# Verificaciones a través de simulaciones.
#
# ### [Didactica 4:](./2_Circuitos_de_adaptacion/1_Didacticas/Didactica_4.ipynb)
#
# Transformador sintonizado.
#
# Transformador de banda ancha.
#
# Divisor capacitivo.
#
# Circuito "PI".
#
# Verificaciones a través de simulaciones.
#
#
# ## Unidad temática III: Amplificadores sintonizados
#
# ### [Didactica 5:](./3_Amplificadores_sintonizados/1_Didacticas/Didactica_5.ipynb)
#
#
# Modelo de dispositivos activos para alta frecuencia.
#
# El amplificador simple sintonizado: ecuaciones de transferencia y diagrama de polos y ceros.
#
#
# ### [Didactica 6:](./3_Amplificadores_sintonizados/1_Didacticas/Didactica_6.ipynb)
#
# El amplificador simple sintonizado: ancho de banda, aproximación de banda angosta. Producto ganancia por ancho de banda.
#
# Amplificador multietapa sincrónico
#
# Verificaciones a través de simulaciones.
#
# ### [Didactica 7:](./3_Amplificadores_sintonizados/1_Didacticas/Didactica_7.ipynb)
#
# El amplificador doble sintonizado: ecuaciones de transferencia, diagrama de polos y ceros, aproximación de Banda Angosta, Transferencia y Ancho de Banda.
#
# Topologías de pasa-bandas Sincrónicos y Butterwoth.
#
# Verificaciones a través de simulaciones.
#
# ### [Didactica 8:](./3_Amplificadores_sintonizados/1_Didacticas/Didactica_8.ipynb)
#
# Análisis de la estabilidad del amplificador.
#
# Factores de Stern y Linvill.
#
#
# ### [Didactica 9:](./3_Amplificadores_sintonizados/1_Didacticas/Didactica_9.ipynb)
#
# Conceptos de Estabilidad, círculos de estabilidad y su ubicación en el diagrama de Smith, factor de estabilidad de Rollett.
#
# Ganancia de transducción.
#
# Desadaptación, Neutralización y Unilateralización.
#
# Verificaciones a través de simulaciones.
#
# ## Unidad temática IV: Ruido eléctrico
#
# ### [Didactica 10:](./4_Ruido/1_Didacticas/Didactica_10.ipynb)
#
# Definiciones y terminología en el estudio del ruido: Relación señal a ruido, Ancho de banda equivalente, Cifra de ruido y Temperatura de ruido.
#
# Ruido térmico en resistencias y redes.
#
# Ruido en dispositivos activos.
#
# Verificaciones empleando simulaciones.
#
# ### [Didactica 11:](./4_Ruido/1_Didacticas/Didactica_11.ipynb)
#
# Amplificadores de bajo ruido (LNA)
#
# Consideraciones de la influencia del ruido en el diseño de amplificadores.
#
# Ancho de banda de ruido equivalente.
#
# Elección de la resistencia óptima del generador desde el punto de vista de ruido.
#
# Verificaciones empleando simulaciones.
#
# ## Unidad temática V: Detección en A.M.
#
# ### [Didactica 12:](./5_Detector_AM/1_Didacticas/Didactica_12.ipynb)
#
# Detector de envolvente, circuito a diodo, rendimiento, resistencia equivalente de entrada,  distorsiones.
#
# Control automático de ganancia mediante sistema directo e inverso.
#
# Verificaciones empleando simulaciones.
#
# ## Unidad temática VI: Amplificadores de potencia sintonizados
#
# ### [Didactica 13:](./6_Amplificadores_potencia_RF/1_Didacticas/Didactica_13.ipynb)
#
# Consideraciones generales de transmisores: modelos de dispositivos activos, filtros.
#
# Comparación entre las clases de amplificadores A, AB, B, C.
#
# El amplificador Clase C
#
#
# ### [Ejercicio 1: Clase B](./6_Amplificadores_potencia_RF/2_Ejercicios/Ejercicio1.ipynb)
#
#
# ### [Ejercicio 2: Clase C](./6_Amplificadores_potencia_RF/2_Ejercicios/Ejercicio2.ipynb)
#
#
# ### [Ejercicio 3: Clase B](./6_Amplificadores_potencia_RF/2_Ejercicios/Ejercicio3.ipynb)
#
#
# ### [Ejercicio 4:Clase C](./6_Amplificadores_potencia_RF/2_Ejercicios/Ejercicio4.ipynb)
#
#
# ### [Ejercicio 5:Clase_B_AM](./6_Amplificadores_potencia_RF/2_Ejercicios/Ejercicio5.ipynb)
#
#
# ### [Ejercicio 6:Clase_C_AM](./6_Amplificadores_potencia_RF/2_Ejercicios/Ejercicio6.ipynb)
#
#
# ### [Ejercicio 7:Clase_C_BLU](./6_Amplificadores_potencia_RF/2_Ejercicios/Ejercicio7.ipynb)
#
#
# ## Unidad temática VII: Mezcladores
#
# ### [Didactica 14:](./7_Mezcladores/1_didactica/Didactica_19.ipynb)
#
#
# Teoría del mezclador y su análisis espectral.
#
# Terminología utilizada en mezcladores.
#
# Ganancia de conversión, nivel de compresión, rango dinámico.
#
# Mezcladores a diodo y mezcladores balanceados.
#
# Verificaciones a través de simulaciones.
#
# Mezcladores y Conversores con dispositivos activos: FET, Bipolar, MOSFET de doble compuerta.
#
# Mezcladores empleando celda de Gilbert.
#
# Verificaciones a través de simulaciones
#
#
# ### [Ejercicio 1: mezclador_jfet](./7_Mezcladores/2_ejercicios/1_mezclador_jfet.ipynb)
#
# ### [Ejercicio 2: mezclador_transistor](./7_Mezcladores/2_ejercicios/2_mezclador_transistor.ipynb)
#
# ### [Ejercicio 3: mezclador_doble_balanceado](./7_Mezcladores/2_ejercicios/3_DobleBalanceado.ipynb)
#
# ### [Ejercicio 4: mezclador_dual](./7_Mezcladores/2_ejercicios/4_Mezclador_dual_mosfet.ipynb)
#
# ### [Ejercicio 5: mezclador_push_pull](./7_Mezcladores/2_ejercicios/5_Push_Pull_MOSFET.ipynb)
#
#
#
# ## Unidad temática VIII: Osciladores sinusoidales
#
#
#
# ### [Didactica 15:](./8_Osciladores/1_didactica/Didactica_17.ipynb)
#
#
# Generalidades de los Osciladores y su clasificación.
#
# Osciladores de resistencia negativa.
#
# Verificaciones a través de simulaciones.
#
# Osciladores Colpitts.
#
# Osciladores Clapp.
#
# Verificaciones a través de simulaciones.
#
# ### [Ejercicio 1: oscilador dos terminales](./8_Osciladores/2_ejercicios/1_Oscilador_dos_terminales_clase.ipynb)
#
# ### [Ejercicio 2: oscilador dos termianales poly](./8_Osciladores/2_ejercicios/1_Oscilador_dos_terminales_poly.ipynb)
#
# ### [Ejercicio 3: oscilador Collpits](./8_Osciladores/2_ejercicios/2_Collpits.ipynb)
#
# ### [Ejercicio 4: oscilador y mezclador ](./8_Osciladores/2_ejercicios/2_Ejercicio_Mezclador_Oscilador.ipynb)
#
#
#
# ## Unidad temática IX: Moduladores y demoduladores angulares.
#
#
# ## Moduladores
#
# ### [Didactica 16:Moduladores](./9_Moduladores_y_demoduladores_frecuencia_angular/Didactica_21.ipynb)
#
# Modulación angular.
#
# Generación de F.M.: directa e indirecta.
#
# Multiplicadores y heterodinaje.
#
# Transistor de reactancia.
#
# Verificaciones a través de simulaciones
#
#
# Modulador Beleskas, Armstrong, diodo varicap.
#
# Verificaciones a través de simulaciones
#
#
#
# Características del detector de FM.
#
# Discriminador por desplazamiento de fase, discriminador Foster–Seeley, detector de razón, detector de cuadratura.
#
# Verificaciones a través de simulaciones
#
#
# ### [1_FM directa](./9_Moduladores_y_demoduladores_frecuencia_angular/1_Moduladores/1_FM_directa.ipynb)
#
#
# ### [2_Modulador_Reactancia_FM](./9_Moduladores_y_demoduladores_frecuencia_angular/1_Moduladores/2_Modulador_Reactancia_FM.ipynb)
#
#
# ### [3_Multiplicadores](./9_Moduladores_y_demoduladores_frecuencia_angular/1_Moduladores/3_Multiplicadores.ipynb)
#
#
# ### [4_Modulador_Armstrong](./9_Moduladores_y_demoduladores_frecuencia_angular/1_Moduladores/4_Modulador_Armstrong.ipynb)
#
#
# ### [5_Modulador_Beleskas](./9_Moduladores_y_demoduladores_frecuencia_angular/1_Moduladores/5_Modulador_Beleskas.ipynb)
#
# ## Demoduladores
#
# Características del detector de FM.
#
# Discriminador por desplazamiento de fase, discriminador Foster–Seeley, detector de razón, detector de cuadratura.
#
# Verificaciones a través de simulaciones
#
# Esquema simplificado de la operación del lazo.
#
# Diagrama en bloques de la operación de un PLL.
#
# Análisis y terminología utilizada en PLL.
#
# El oscilador de lazo (VCO).
#
#
# ### [1_Demoduladores_angulares_pendiente](./9_Moduladores_y_demoduladores_frecuencia_angular/2_Demoduladores/1_Demoduladores_angulares_pendiente.ipynb)
#
#
# ### [2_Demodulador_Foster_Seeley](./9_Moduladores_y_demoduladores_frecuencia_angular/2_Demoduladores/2_Demodulador_Foster_Seeley.ipynb)
#
#
# ### [3_Detector_de_relacion](./9_Moduladores_y_demoduladores_frecuencia_angular/2_Demoduladores/3_Detector_de_relacion.ipynb)
#
#
# ### [4_detector_cuadratura](./9_Moduladores_y_demoduladores_frecuencia_angular/2_Demoduladores/4_detector_cuadratura.ipynb)

# %% [markdown]
# ## Practicas de Parciales
#
# ### Segundo Parcial
#
#
# ### [20201130](./12_parciales/2_segundo/20201130_lunes/segundo_parcial_Lunes.ipynb)
#
#
# ### [20201203](./12_parciales/2_segundo/20201203_jueves/segundo_parcial_jueves.ipynb)
#
#
#
# ### [20201223](./12_parciales/2_segundo/20201223_recuperatorio_miercoles/segundo_parcial_Miercoles.ipynb)
